# %% [markdown]
# # Detection of nCoV-19 from Hybrid Dataset of CXR Images using Deep Convolutional Neural Network
#  [**Paper Link**](https://doi.org/10.14569/IJACSA.2021.01205561)

# %% [markdown]
# # Imports and Installs

# %%
# !pip install lime -q

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import LSTM, Dense, Reshape
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from sklearn.preprocessing import label_binarize
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt


from lime import lime_image
from lime.wrappers.scikit_image import SegmentationAlgorithm
from skimage.io import imread
from skimage.transform import resize
from skimage.segmentation import mark_boundaries


from shutil import copyfile
import pandas as pd
import numpy as np 
import cv2
import os
# Out:
# 2025-05-02 23:31:50.617062: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746228710.911391      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746228710.993366      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Helper Functions

# %%
def preprocess_image(image_path):
    try:
        img = imread(image_path, as_gray=False)
        img = resize(img, (224, 224), anti_aliasing=True)
        if len(img.shape) == 2:
            img_rgb = np.stack([img] * 3, axis=-1)
        elif img.shape[-1] == 1:
            img_rgb = np.repeat(img, 3, axis=-1)
        else:
            img_rgb = img
        img_normalized = img_rgb / 255.0 if img_rgb.max() > 1 else img_rgb
        if len(img.shape) == 2 or (len(img.shape) == 3 and np.all(img[:, :, 0] == img[:, :, 1]) and np.all(img[:, :, 1] == img[:, :, 2])):
            img_viz = img if len(img.shape) == 2 else img[:, :, 0]
        else:
            img_viz = img_rgb
        return img_normalized, img_viz
    except Exception as e:
        print(f"Error preprocessing image: {e}")
        return None, None

# %%
def split_train_val(data_dir, output_dir, train_ratio=0.85):  # 70/(70+10) = 0.875
    classes = ['covid19', 'normal', 'pneumonia']
    os.makedirs(output_dir, exist_ok=True)
    
    for split in ['train', 'val']:
        for cls in classes:
            os.makedirs(os.path.join(output_dir, split, cls), exist_ok=True)
    
    for cls in classes:
        class_dir = os.path.join(data_dir, cls)
        images = [f for f in os.listdir(class_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]
        
        train_imgs, val_imgs = train_test_split(images, train_size=train_ratio, random_state=42)
        
        for img in train_imgs:
            copyfile(os.path.join(class_dir, img), os.path.join(output_dir, 'train', cls, img))
        for img in val_imgs:
            copyfile(os.path.join(class_dir, img), os.path.join(output_dir, 'val', cls, img))
    
    print("Train-validation split completed.")

# %% [markdown]
# # plotting functions for train test tracing

# %%
def plot_learning_curves(history):
    plt.figure(figsize=(12, 5))
    
    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %%
def plot_multiclass_roc_pr(y_true, y_probs, class_names):
    n_classes = len(class_names)
    y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

    plt.figure(figsize=(14, 6))

    # ROC Curves
    plt.subplot(1, 2, 1)
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f"{class_names[i]} (AUC = {roc_auc:.2f})")
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.title('Multiclass ROC Curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()

    # PR Curves
    plt.subplot(1, 2, 2)
    for i in range(n_classes):
        precision, recall, _ = precision_recall_curve(y_true_bin[:, i], y_probs[:, i])
        ap = average_precision_score(y_true_bin[:, i], y_probs[:, i])
        plt.plot(recall, precision, lw=2, label=f"{class_names[i]} (AP = {ap:.2f})")
    plt.title('Multiclass Precision-Recall Curve')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
def plot_confusion_matrix(model, test_generator):
    Y_true = test_generator.classes
    Y_pred_probs = model.predict(test_generator)
    Y_pred = np.argmax(Y_pred_probs, axis=1)

    cm = confusion_matrix(Y_true, Y_pred)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_generator.class_indices.keys())
    disp.plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.show()

# %%
def predict_fn(images):
    images = np.array(images)
    if images.shape[-1] != 3:
        images = np.repeat(images, 3, axis=-1)
    images = np.clip(images, 0, 1)
    return model.predict(images, verbose=0)

# %% [markdown]
# # XAI functions for imgs

# %%
def explain_with_lime(model, image_paths_with_labels):
    explainer = lime_image.LimeImageExplainer()
    segmenter = SegmentationAlgorithm('quickshift', kernel_size=2, max_dist=100, ratio=0.2)

    for image_path, class_name in image_paths_with_labels:
        img_normalized, img_viz = preprocess_image(image_path)
        if img_normalized is None:
            print(f"Skipping {image_path} due to preprocessing error.")
            continue

        try:
            explanation = explainer.explain_instance(
                img_normalized,
                predict_fn,
                top_labels=3,
                hide_color=None,
                num_samples=500,
                segmentation_fn=segmenter
            )
        except Exception as e:
            print(f"Error explaining image {image_path}: {e}")
            continue

        pred = model.predict(np.expand_dims(img_normalized, axis=0), verbose=0)
        predicted_class = class_labels[np.argmax(pred)]

        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))

        ax1.imshow(img_viz, cmap='gray' if len(img_viz.shape) == 2 else None)
        ax1.set_title(f'Original ({class_name})\nPredicted: {predicted_class}')
        ax1.axis('off')

        temp, mask = explanation.get_image_and_mask(
            explanation.top_labels[0],
            positive_only=True,
            num_features=5,
            hide_rest=False
        )

        base_image = img_viz
        if len(base_image.shape) == 2:
            overlay = np.zeros_like(base_image)
            overlay[mask == 1] = 1
            alpha = 0.3
            highlighted_image = (1 - alpha) * base_image + alpha * overlay
            highlighted_image = np.clip(highlighted_image, 0, 1)
            cmap = 'gray'
        else:
            overlay = np.zeros_like(base_image)
            overlay[mask == 1] = [1, 0, 0]
            alpha = 0.3
            highlighted_image = (1 - alpha) * base_image + alpha * overlay
            highlighted_image = np.clip(highlighted_image, 0, 1)
            cmap = None

        highlighted_image = mark_boundaries(highlighted_image, mask, color=(1, 0, 0), mode='thick')
        ax2.imshow(highlighted_image, cmap=cmap)
        ax2.set_title('LIME Highlights')
        ax2.axis('off')

        plt.tight_layout()
        plt.show()

        print(f"Image: {image_path}")
        print(f"Predicted probabilities: {dict(zip(class_labels, pred[0]))}\n")

# %%
def get_gradcam_heatmap(model, img_array, last_conv_layer_name, pred_index=None):
    try:
        conv_layer = model.get_layer(last_conv_layer_name)
    except ValueError:
        print("Available layers:")
        for layer in model.layers:
            print(layer.name)
        raise ValueError(f"Layer '{last_conv_layer_name}' not found in the model. Check layer names above.")

    grad_model = tf.keras.models.Model(
        inputs=[model.inputs],
        outputs=[conv_layer.output, model.output]
    )
    
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]
    
    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # Apply ReLU and normalize the heatmap
    heatmap = tf.maximum(heatmap, 0)
    max_val = tf.reduce_max(heatmap)
    if max_val > 0:
        heatmap = heatmap / max_val
        heatmap_np = heatmap.numpy()  # tensor → numpy
    else:
        print("Warning: Heatmap is all zeros, returning empty heatmap")
        heatmap_np = np.zeros_like(heatmap.numpy())  # explicitly convert tensor to numpy before using np.zeros_like
    
    return heatmap_np


def overlay_heatmap(heatmap, original_img, alpha=0.4):
    heatmap = cv2.resize(heatmap, (original_img.shape[1], original_img.shape[0]))
    
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    
    if original_img.max() <= 1.0:
        original_img = original_img * 255
    original_img = np.uint8(original_img)
    
    superimposed_img = heatmap * alpha + original_img
    superimposed_img = np.clip(superimposed_img, 0, 255).astype(np.uint8)
    return superimposed_img

def apply_grad_cam(model, image_path, class_label, class_labels, last_conv_layer_name='conv2d_19', save_dir='.'):
    img = cv2.imread(image_path)
    if img is None:
        raise ValueError(f"Failed to load image from {image_path}")
    
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))
    sample_img = img.astype(np.float32) / 255.0
    sample_img_array = np.expand_dims(sample_img, axis=0)

    print(f"\nProcessing image: {image_path}")
    print("Sample image shape:", sample_img.shape)
    print("Sample image min/max:", sample_img.min(), sample_img.max())
    if sample_img_array.shape != (1, 224, 224, 3):
        raise ValueError(f"Sample image shape {sample_img_array.shape} does not match expected shape (1, 224, 224, 3)")

    predictions = model.predict(sample_img_array, verbose=1)
    predicted_class_idx = np.argmax(predictions[0])
    predicted_class = class_labels[predicted_class_idx]
    print("Predicted class:", predicted_class)
    print("Predictions:", predictions[0])

    heatmap = get_gradcam_heatmap(model, sample_img_array, last_conv_layer_name, pred_index=predicted_class_idx)
    print("Heatmap shape:", heatmap.shape)
    print("Heatmap min/max:", heatmap.min(), heatmap.max())

    superimposed_img = overlay_heatmap(heatmap, sample_img)


    plt.subplot(1, 2, 1)
    plt.title(f'Original Image\n(True: {class_label})')
    plt.imshow(sample_img)
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title(f'Grad-CAM\n(Pred: {predicted_class})')
    plt.imshow(superimposed_img)
    plt.axis('off')

    plt.tight_layout()

    save_filename = f'grad_cam_{class_label}.png'
    save_path = os.path.join(save_dir, save_filename)
    plt.savefig(save_path, bbox_inches='tight')
    print(f"Plot saved to: {os.path.abspath(save_path)}")

    plt.show()

    plt.close()

# %%
def deeplift(model, img, baseline=None, pred_index=None):
    if baseline is None:
        baseline = np.zeros_like(img)
    img = tf.convert_to_tensor(img, dtype=tf.float32)
    baseline = tf.convert_to_tensor(baseline, dtype=tf.float32)
    
    diff = img - baseline
    
    with tf.GradientTape() as tape:
        tape.watch(img)
        preds = model(img)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        score = preds[:, pred_index]
    
    grads = tape.gradient(score, img)
    multipliers = grads
    contributions = diff * multipliers  
    heatmap = tf.reduce_sum(tf.abs(contributions), axis=-1).numpy()
    heatmap = np.maximum(heatmap, 0) / (np.max(heatmap) + 1e-10) 
    return heatmap, pred_index

def display_heatmap(img, heatmap, alpha=0.5):
    if img.ndim == 4:
        img = img[0]
    if heatmap.ndim == 3:
        heatmap = heatmap[0]
    
    img = np.uint8(255 * (img - img.min()) / (img.max() - img.min() + 1e-10))
    
    heatmap = np.uint8(255 * heatmap)
    heatmap = tf.image.resize(heatmap[..., np.newaxis], (img.shape[0], img.shape[1])).numpy()[..., 0]
    heatmap = np.uint8(plt.cm.jet(heatmap)[..., :3] * 255)
    
    superimposed_img = heatmap * alpha + img * (1 - alpha)
    return np.uint8(superimposed_img)

# %%
def permutation_importance(image, model, class_index, model_name, raw_image, patch_size=32):
    image = np.expand_dims(image, axis=0)
    correct_prob = model.predict(image, verbose=0)[0, class_index]

    h, w = image.shape[1], image.shape[2]
    importance_map = np.zeros((h // patch_size, w // patch_size))

    for i in range(0, h, patch_size):
        for j in range(0, w, patch_size):
            permuted = image.copy()

            for c in range(3):
                permuted[0, i:i+patch_size, j:j+patch_size, c] = np.random.rand(patch_size, patch_size)

            pred_prob = model.predict(permuted, verbose=0)[0, class_index]
            importance = correct_prob - pred_prob
            importance_map[i // patch_size, j // patch_size] = importance

    importance_map = (importance_map - importance_map.min()) / (importance_map.max() - importance_map.min() + 1e-8)

    heatmap = cv2.resize(importance_map, (w, h))

    plt.figure(figsize=(6, 6))
    plt.imshow(raw_image)
    plt.imshow(heatmap, cmap='hot', alpha=0.5)
    plt.title(f"{model_name}")
    plt.axis('off')
    plt.colorbar()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Load data and apply Augmentation

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_281.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_1.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_256.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_221.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_138.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_93.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_198.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_137.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_120.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_13.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_40.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_217.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_3.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_286.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_191.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_245.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_58.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_25.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_116.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_2.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_39.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_282.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_223.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_152.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_175.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_92.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_81.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_275.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_199.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_183.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_174.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_227.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_149.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_205.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_155.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_212.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_45.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_298.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_56.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_67.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_228.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_197.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_261.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_234.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_167.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_154.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_59.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_273.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_169.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_185.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_258.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_272.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_283.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_192.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_70.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_129.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_277.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_71.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_259.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_173.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_79.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_42.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_113.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_220.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_48.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_162.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_206.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_216.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_241.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_157.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_84.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_209.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_176.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_179.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_139.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_214.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_170.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_26.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_202.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_80.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_211.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_127.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_72.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_21.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_77.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_125.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_289.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_260.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_62.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_4.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_237.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_250.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_36.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_161.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_98.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_30.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_24.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_60.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_263.png
# /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_165.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_301.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_213.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_6.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_37.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_133.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_22.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_180.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_265.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_156.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_103.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_0.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_126.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_160.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_243.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_164.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_287.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_288.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_166.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_278.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_200.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_251.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_55.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_292.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_102.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_188.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_181.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_11.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_262.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_18.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_280.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_16.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_285.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_87.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_112.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_31.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_225.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_20.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_210.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_172.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_144.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_177.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_182.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_293.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_131.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_51.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_23.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_254.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_66.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_203.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_54.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_142.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_19.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_268.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_96.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_63.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_276.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_64.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_231.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_284.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_297.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_193.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_224.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_91.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_222.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_178.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_134.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_110.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_123.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_246.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_296.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_7.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_74.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_115.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_109.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_34.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_186.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_78.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_100.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_189.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_130.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_49.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_255.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_232.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_94.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_53.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_105.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_300.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_52.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_95.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_270.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_128.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_141.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_148.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_207.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_235.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_27.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_290.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_35.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_43.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_171.png
# /kaggle/input/feature-selelcted-dataset/test/normal/image_279.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_253.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_85.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_150.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_159.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_108.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_69.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_135.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_44.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_57.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_248.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_264.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_76.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_101.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_12.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_208.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_124.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_201.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_269.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_187.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_28.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_295.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_153.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_5.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_267.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_89.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_184.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_140.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_266.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_82.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_119.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_114.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_244.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_294.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_168.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_15.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_233.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_194.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_121.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_41.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_247.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_147.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_106.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_33.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_90.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_32.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_238.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_236.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_143.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_196.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_299.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_274.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_97.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_271.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_29.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_86.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_218.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_219.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_104.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_88.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_99.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_163.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_158.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_204.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_249.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_229.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_46.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_195.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_10.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_111.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_136.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_38.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_118.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_83.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_107.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_242.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_50.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_122.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_117.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_151.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_226.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_190.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_17.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_14.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_65.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_8.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_146.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_68.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_61.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_47.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_215.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_73.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_145.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_239.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_240.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_75.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_252.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_9.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_230.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_257.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_291.png
# /kaggle/input/feature-selelcted-dataset/test/covid19/image_132.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_281.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_418.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1173.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_328.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1000.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_761.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_256.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_372.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_512.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1125.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_583.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_37.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1113.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_891.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_22.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_508.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_844.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_85.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_150.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_855.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1039.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1027.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_138.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_265.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_789.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_435.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1162.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_787.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_859.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_990.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_0.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_120.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_836.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_311.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_824.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_644.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_376.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_964.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1178.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1152.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_615.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1174.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_645.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_432.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1031.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_459.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1067.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_959.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_578.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_363.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1052.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_286.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_401.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_135.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_44.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1122.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_620.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1024.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_243.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_948.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_164.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_287.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_521.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_738.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_548.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_25.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_101.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_614.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_544.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_397.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_757.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_282.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_208.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_815.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_124.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_200.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_609.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1160.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_292.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_529.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_906.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1191.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_961.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_187.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_661.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_966.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_901.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_943.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_838.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1108.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_524.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_295.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_599.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_335.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_345.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_715.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_864.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_183.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_490.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_407.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_751.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_374.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_89.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_692.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_554.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1064.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1061.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_332.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_576.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_689.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_262.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_862.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_985.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_995.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_149.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_571.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_619.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_205.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_155.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_746.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_626.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_114.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_492.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_31.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1133.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_708.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_845.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_648.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1126.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_946.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_464.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_537.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_681.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1020.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_325.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_313.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1055.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_622.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_172.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_656.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_682.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_840.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_893.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1014.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1092.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_402.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_520.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1132.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_182.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_993.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1042.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_980.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1101.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_565.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_367.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_885.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1038.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_796.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_51.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_23.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_860.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_832.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1166.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1200.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_886.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_324.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_353.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1077.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_234.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_147.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_106.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_167.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_809.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_154.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1145.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1168.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_59.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_696.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_203.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_875.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_54.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_679.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_526.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_142.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_32.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_849.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_854.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_143.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_258.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_688.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_866.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_944.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_803.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_569.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1115.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_652.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_734.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_19.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_274.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_988.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_271.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_29.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_63.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_542.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_276.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_86.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_297.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_192.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_676.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_601.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_193.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1138.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_535.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_224.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_222.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1074.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1149.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1102.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_99.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_322.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1148.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_883.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_178.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1203.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_134.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1053.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_259.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_173.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_423.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_873.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1037.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_861.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1170.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_304.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_310.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_42.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_636.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_759.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1202.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_994.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_467.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_699.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1139.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_517.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1119.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_731.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_394.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_48.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1009.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_229.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_162.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_296.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_7.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_956.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_414.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1012.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_617.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_629.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_783.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_728.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_216.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_195.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1063.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1034.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_800.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_241.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1161.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1091.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_967.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_736.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1003.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1157.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_877.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_157.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_479.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_355.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1107.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_336.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1190.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1057.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_315.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_727.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_937.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_415.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_950.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_84.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_481.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_828.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_693.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_209.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1204.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_777.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_83.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1135.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_784.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_908.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_684.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1071.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_752.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_654.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1185.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_763.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_739.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_179.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_910.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1021.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_255.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1005.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_139.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_214.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_741.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_502.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_170.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_26.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_493.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_202.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_117.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_785.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_226.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_53.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_771.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1159.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_17.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_128.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_555.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_80.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1175.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_522.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_852.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_922.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_562.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1080.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_694.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_632.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_665.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1117.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_456.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1085.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_791.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_730.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_47.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1036.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_395.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_501.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_853.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_215.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1076.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_690.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_72.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1127.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_77.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_896.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_347.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_125.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1018.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_368.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_349.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_412.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_760.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_240.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_235.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_610.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_559.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_551.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_773.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_444.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_669.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_868.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_519.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_482.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_631.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_484.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_594.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_718.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_591.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1083.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1006.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1004.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1017.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_36.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_580.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_491.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_755.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_670.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1089.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_257.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1142.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_1109.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_965.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_797.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_436.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_863.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_373.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_606.png
# /kaggle/input/feature-selelcted-dataset/train/pneumonia/image_279.png
# ...
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_921.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_566.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_233.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_543.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_668.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_472.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_194.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_858.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_545.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_513.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_121.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_989.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_131.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1197.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_744.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_825.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_41.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_505.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_348.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_351.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_902.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_247.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_653.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_634.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_66.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1182.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_538.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_928.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_90.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_673.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_488.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_386.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_330.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_810.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_735.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_884.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_486.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_895.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_236.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_528.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1013.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_695.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_588.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_268.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_299.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_835.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_97.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_949.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_638.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_346.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_64.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_876.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_660.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_231.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_283.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1022.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1051.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_983.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_439.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_430.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_842.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1093.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1029.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1192.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1007.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_867.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_702.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_700.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_219.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_602.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_104.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_277.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1100.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_575.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_600.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_927.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1008.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1189.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1124.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_647.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_951.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_455.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_249.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_658.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_110.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1144.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_717.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_533.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_527.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_431.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_541.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_123.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_882.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_474.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_729.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_246.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_716.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_417.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_888.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_929.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_710.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_442.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_113.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_675.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_939.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_720.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_850.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_938.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_826.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_74.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_801.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_968.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_516.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_546.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1176.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_475.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_805.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_317.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_111.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_664.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_837.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_846.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_399.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1112.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_878.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_478.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_737.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_587.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_480.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_176.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_309.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_189.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_130.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_813.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_498.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_998.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_865.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_549.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_781.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_618.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_686.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_798.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1097.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1079.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_643.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_897.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_232.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_50.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_358.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_378.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_122.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_556.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_843.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1181.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_151.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_326.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_930.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1041.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_940.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_105.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_300.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_52.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_811.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_721.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_723.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_936.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_577.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_497.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_270.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1114.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1078.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_996.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_698.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_887.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_703.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_612.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_903.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_642.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1172.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1201.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1019.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_68.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_329.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1130.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1045.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_558.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_366.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1035.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1105.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1058.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_924.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_21.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_590.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_978.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_872.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_764.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_73.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_792.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_145.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_572.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_890.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_666.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_762.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_289.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_935.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_75.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_252.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_354.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1198.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1094.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_477.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_27.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_960.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_623.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_35.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_971.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_974.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_237.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_250.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1184.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_340.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_496.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_745.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_808.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_413.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_857.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_881.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_907.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_596.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_352.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1128.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_132.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_1073.png
# /kaggle/input/feature-selelcted-dataset/train/covid19/image_817.png

# %%
train_dir = '/kaggle/input/feature-selelcted-dataset/train'
output_dir = '/kaggle/working/chest-xray-covid19-pneumonia/split'
split_train_val(train_dir, output_dir)
test_dir = '/kaggle/input/feature-selelcted-dataset/test'

train_datagen = ImageDataGenerator(
    rescale=1./255,
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    os.path.join(output_dir, 'train'),
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    classes=['covid19', 'normal', 'pneumonia']
)

validation_generator = val_test_datagen.flow_from_directory(
    os.path.join(output_dir, 'val'),
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    classes=['covid19', 'normal', 'pneumonia']
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    classes=['covid19', 'normal', 'pneumonia'],
    shuffle=False
)
# Out:
# Train-validation split completed.
# Found 1022 images belonging to 3 classes.
# Found 183 images belonging to 3 classes.
# Found 302 images belonging to 3 classes.

# %% [markdown]
# # Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def create_cnn_model(input_shape=(244, 244, 3), num_classes=2):

    inputs = layers.Input(shape=input_shape)

    x = layers.Conv2D(filters=32, kernel_size=(5, 5), padding='same', activation=None,name="conv_layer")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Flatten()(x)
    
    x = layers.Dense(units=128, activation=None)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    
    outputs = layers.Dense(units=num_classes, activation='softmax')(x)
    
    model = models.Model(inputs=inputs, outputs=outputs)
    
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.003)
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
model = create_cnn_model(input_shape=(224, 224, 3), num_classes=3)

model.summary()
# Out:
# I0000 00:00:1746228741.136234      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1746228741.136987      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_layer (Conv2D)                  │ (None, 224, 224, 32)        │           2,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 224, 224, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 224, 224, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1605632)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │     205,521,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_1 (ReLU)                       │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 205,524,483 (784.01 MB)
#  Trainable params: 205,524,163 (784.01 MB)
#  Non-trainable params: 320 (1.25 KB)

# %% [markdown]
# # Train and Test

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)
history = model.fit(
    train_generator,
    epochs=500,
    validation_data=validation_generator,
    callbacks=[reduce_lr]
)

test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")


# model.save('/kaggle/working/cnn_lstm_pneumonia_model.h5')
# Out:
# Epoch 1/500
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746228746.555659     121 service.cc:148] XLA service 0x7d1ee4005350 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746228746.556768     121 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746228746.556792     121 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746228746.883662     121 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  1/64 ━━━━━━━━━━━━━━━━━━━━ 10:05 10s/step - accuracy: 0.1250 - loss: 1.5738
# I0000 00:00:1746228752.329280     121 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 22s 193ms/step - accuracy: 0.5884 - loss: 1.1816 - val_accuracy: 0.4372 - val_loss: 1.0828 - learning_rate: 0.0030
# Epoch 2/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7486 - loss: 0.5695 - val_accuracy: 0.6339 - val_loss: 0.7723 - learning_rate: 0.0030
# Epoch 3/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.8473 - loss: 0.3801 - val_accuracy: 0.7104 - val_loss: 0.5775 - learning_rate: 0.0030
# Epoch 4/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.8848 - loss: 0.3123 - val_accuracy: 0.8306 - val_loss: 0.4428 - learning_rate: 0.0030
# Epoch 5/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.9269 - loss: 0.2203 - val_accuracy: 0.8306 - val_loss: 0.4166 - learning_rate: 0.0030
# Epoch 6/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.9596 - loss: 0.1381 - val_accuracy: 0.7541 - val_loss: 0.6173 - learning_rate: 0.0030
# Epoch 7/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.9744 - loss: 0.1012 - val_accuracy: 0.6066 - val_loss: 1.3707 - learning_rate: 0.0030
# Epoch 8/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.9483 - loss: 0.1246 - val_accuracy: 0.6393 - val_loss: 1.1016 - learning_rate: 0.0030
# Epoch 9/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.9950 - loss: 0.0444 - val_accuracy: 0.8470 - val_loss: 0.4846 - learning_rate: 6.0000e-04
# Epoch 10/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.9991 - loss: 0.0240 - val_accuracy: 0.8579 - val_loss: 0.4261 - learning_rate: 6.0000e-04
# Epoch 11/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.9962 - loss: 0.0252 - val_accuracy: 0.8689 - val_loss: 0.4316 - learning_rate: 6.0000e-04
# Epoch 12/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.9964 - loss: 0.0219 - val_accuracy: 0.8798 - val_loss: 0.4063 - learning_rate: 1.2000e-04
# Epoch 13/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.9995 - loss: 0.0235 - val_accuracy: 0.8798 - val_loss: 0.3965 - learning_rate: 1.2000e-04
# Epoch 14/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 0.8689 - val_loss: 0.3987 - learning_rate: 1.2000e-04
# Epoch 15/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.9902 - loss: 0.0330 - val_accuracy: 0.8689 - val_loss: 0.4004 - learning_rate: 1.2000e-04
# Epoch 16/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.8689 - val_loss: 0.4018 - learning_rate: 1.2000e-04
# Epoch 17/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.8689 - val_loss: 0.4024 - learning_rate: 2.4000e-05
# Epoch 18/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9977 - loss: 0.0162 - val_accuracy: 0.8689 - val_loss: 0.4039 - learning_rate: 2.4000e-05
# Epoch 19/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9985 - loss: 0.0180 - val_accuracy: 0.8689 - val_loss: 0.4049 - learning_rate: 2.4000e-05
# Epoch 20/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9973 - loss: 0.0171 - val_accuracy: 0.8689 - val_loss: 0.4037 - learning_rate: 4.8000e-06
# Epoch 21/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9969 - loss: 0.0216 - val_accuracy: 0.8743 - val_loss: 0.4037 - learning_rate: 4.8000e-06
# Epoch 22/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9977 - loss: 0.0191 - val_accuracy: 0.8689 - val_loss: 0.4046 - learning_rate: 4.8000e-06
# Epoch 23/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 0.8689 - val_loss: 0.4045 - learning_rate: 1.0000e-06
# Epoch 24/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9974 - loss: 0.0265 - val_accuracy: 0.8743 - val_loss: 0.4047 - learning_rate: 1.0000e-06
# Epoch 25/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.9996 - loss: 0.0212 - val_accuracy: 0.8689 - val_loss: 0.4044 - learning_rate: 1.0000e-06
# Epoch 26/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.9952 - loss: 0.0271 - val_accuracy: 0.8689 - val_loss: 0.4044 - learning_rate: 1.0000e-06
# Epoch 27/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.9980 - loss: 0.0191 - val_accuracy: 0.8743 - val_loss: 0.4052 - learning_rate: 1.0000e-06
# Epoch 28/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9948 - loss: 0.0347 - val_accuracy: 0.8743 - val_loss: 0.4052 - learning_rate: 1.0000e-06
# Epoch 29/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9976 - loss: 0.0178 - val_accuracy: 0.8743 - val_loss: 0.4054 - learning_rate: 1.0000e-06
# Epoch 30/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9986 - loss: 0.0151 - val_accuracy: 0.8743 - val_loss: 0.4046 - learning_rate: 1.0000e-06
# Epoch 31/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9961 - loss: 0.0231 - val_accuracy: 0.8743 - val_loss: 0.4047 - learning_rate: 1.0000e-06
# Epoch 32/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9995 - loss: 0.0178 - val_accuracy: 0.8743 - val_loss: 0.4045 - learning_rate: 1.0000e-06
# Epoch 33/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9991 - loss: 0.0192 - val_accuracy: 0.8743 - val_loss: 0.4047 - learning_rate: 1.0000e-06
# Epoch 34/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.8743 - val_loss: 0.4047 - learning_rate: 1.0000e-06
# Epoch 35/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9954 - loss: 0.0248 - val_accuracy: 0.8743 - val_loss: 0.4050 - learning_rate: 1.0000e-06
# Epoch 36/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9987 - loss: 0.0169 - val_accuracy: 0.8743 - val_loss: 0.4054 - learning_rate: 1.0000e-06
# Epoch 37/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.8743 - val_loss: 0.4054 - learning_rate: 1.0000e-06
# Epoch 38/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.8743 - val_loss: 0.4046 - learning_rate: 1.0000e-06
# Epoch 39/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9976 - loss: 0.0160 - val_accuracy: 0.8743 - val_loss: 0.4046 - learning_rate: 1.0000e-06
# Epoch 40/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9988 - loss: 0.0205 - val_accuracy: 0.8743 - val_loss: 0.4048 - learning_rate: 1.0000e-06
# Epoch 41/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9992 - loss: 0.0131 - val_accuracy: 0.8743 - val_loss: 0.4049 - learning_rate: 1.0000e-06
# Epoch 42/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9952 - loss: 0.0174 - val_accuracy: 0.8743 - val_loss: 0.4047 - learning_rate: 1.0000e-06
# Epoch 43/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9992 - loss: 0.0180 - val_accuracy: 0.8743 - val_loss: 0.4049 - learning_rate: 1.0000e-06
# Epoch 44/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9958 - loss: 0.0225 - val_accuracy: 0.8743 - val_loss: 0.4053 - learning_rate: 1.0000e-06
# Epoch 45/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.8743 - val_loss: 0.4050 - learning_rate: 1.0000e-06
# Epoch 46/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9931 - loss: 0.0299 - val_accuracy: 0.8743 - val_loss: 0.4054 - learning_rate: 1.0000e-06
# Epoch 47/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9974 - loss: 0.0204 - val_accuracy: 0.8743 - val_loss: 0.4045 - learning_rate: 1.0000e-06
# Epoch 48/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9984 - loss: 0.0222 - val_accuracy: 0.8743 - val_loss: 0.4052 - learning_rate: 1.0000e-06
# Epoch 49/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9980 - loss: 0.0244 - val_accuracy: 0.8743 - val_loss: 0.4050 - learning_rate: 1.0000e-06
# Epoch 50/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9951 - loss: 0.0231 - val_accuracy: 0.8743 - val_loss: 0.4047 - learning_rate: 1.0000e-06
# Epoch 51/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.8689 - val_loss: 0.4051 - learning_rate: 1.0000e-06
# Epoch 52/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9974 - loss: 0.0135 - val_accuracy: 0.8743 - val_loss: 0.4049 - learning_rate: 1.0000e-06
# Epoch 53/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9992 - loss: 0.0195 - val_accuracy: 0.8743 - val_loss: 0.4052 - learning_rate: 1.0000e-06
# Epoch 54/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9980 - loss: 0.0173 - val_accuracy: 0.8743 - val_loss: 0.4050 - learning_rate: 1.0000e-06
# Epoch 55/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9925 - loss: 0.0300 - val_accuracy: 0.8743 - val_loss: 0.4056 - learning_rate: 1.0000e-06
# Epoch 56/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.8743 - val_loss: 0.4060 - learning_rate: 1.0000e-06
# Epoch 57/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9999 - loss: 0.0121 - val_accuracy: 0.8743 - val_loss: 0.4056 - learning_rate: 1.0000e-06
# Epoch 58/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9976 - loss: 0.0173 - val_accuracy: 0.8743 - val_loss: 0.4056 - learning_rate: 1.0000e-06
# Epoch 59/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9981 - loss: 0.0162 - val_accuracy: 0.8689 - val_loss: 0.4053 - learning_rate: 1.0000e-06
# Epoch 60/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9953 - loss: 0.0211 - val_accuracy: 0.8689 - val_loss: 0.4046 - learning_rate: 1.0000e-06
# Epoch 61/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9968 - loss: 0.0238 - val_accuracy: 0.8743 - val_loss: 0.4056 - learning_rate: 1.0000e-06
# Epoch 62/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 0.8743 - val_loss: 0.4054 - learning_rate: 1.0000e-06
# Epoch 63/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.8689 - val_loss: 0.4059 - learning_rate: 1.0000e-06
# Epoch 64/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9975 - loss: 0.0210 - val_accuracy: 0.8689 - val_loss: 0.4060 - learning_rate: 1.0000e-06
# Epoch 65/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9853 - loss: 0.0507 - val_accuracy: 0.8689 - val_loss: 0.4054 - learning_rate: 1.0000e-06
# Epoch 66/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.8689 - val_loss: 0.4059 - learning_rate: 1.0000e-06
# Epoch 67/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9998 - loss: 0.0182 - val_accuracy: 0.8743 - val_loss: 0.4056 - learning_rate: 1.0000e-06
# Epoch 68/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9961 - loss: 0.0270 - val_accuracy: 0.8689 - val_loss: 0.4060 - learning_rate: 1.0000e-06
# Epoch 69/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9985 - loss: 0.0154 - val_accuracy: 0.8743 - val_loss: 0.4055 - learning_rate: 1.0000e-06
# Epoch 70/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9976 - loss: 0.0147 - val_accuracy: 0.8743 - val_loss: 0.4063 - learning_rate: 1.0000e-06
# Epoch 71/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9998 - loss: 0.0150 - val_accuracy: 0.8689 - val_loss: 0.4064 - learning_rate: 1.0000e-06
# Epoch 72/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9994 - loss: 0.0181 - val_accuracy: 0.8689 - val_loss: 0.4063 - learning_rate: 1.0000e-06
# Epoch 73/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9987 - loss: 0.0175 - val_accuracy: 0.8689 - val_loss: 0.4062 - learning_rate: 1.0000e-06
# Epoch 74/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9997 - loss: 0.0205 - val_accuracy: 0.8689 - val_loss: 0.4064 - learning_rate: 1.0000e-06
# Epoch 75/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9988 - loss: 0.0208 - val_accuracy: 0.8689 - val_loss: 0.4061 - learning_rate: 1.0000e-06
# Epoch 76/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9989 - loss: 0.0199 - val_accuracy: 0.8689 - val_loss: 0.4062 - learning_rate: 1.0000e-06
# Epoch 77/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9978 - loss: 0.0200 - val_accuracy: 0.8689 - val_loss: 0.4061 - learning_rate: 1.0000e-06
# Epoch 78/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9992 - loss: 0.0160 - val_accuracy: 0.8689 - val_loss: 0.4055 - learning_rate: 1.0000e-06
# Epoch 79/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9987 - loss: 0.0169 - val_accuracy: 0.8689 - val_loss: 0.4046 - learning_rate: 1.0000e-06
# Epoch 80/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9895 - loss: 0.0365 - val_accuracy: 0.8743 - val_loss: 0.4055 - learning_rate: 1.0000e-06
# Epoch 81/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9998 - loss: 0.0210 - val_accuracy: 0.8689 - val_loss: 0.4061 - learning_rate: 1.0000e-06
# Epoch 82/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 0.8689 - val_loss: 0.4059 - learning_rate: 1.0000e-06
# Epoch 83/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9959 - loss: 0.0233 - val_accuracy: 0.8689 - val_loss: 0.4067 - learning_rate: 1.0000e-06
# Epoch 84/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9989 - loss: 0.0137 - val_accuracy: 0.8689 - val_loss: 0.4066 - learning_rate: 1.0000e-06
# Epoch 85/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9965 - loss: 0.0209 - val_accuracy: 0.8743 - val_loss: 0.4060 - learning_rate: 1.0000e-06
# Epoch 86/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 0.8743 - val_loss: 0.4061 - learning_rate: 1.0000e-06
# Epoch 87/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9976 - loss: 0.0199 - val_accuracy: 0.8689 - val_loss: 0.4067 - learning_rate: 1.0000e-06
# Epoch 88/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0218 - val_accuracy: 0.8743 - val_loss: 0.4076 - learning_rate: 1.0000e-06
# Epoch 89/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9994 - loss: 0.0155 - val_accuracy: 0.8743 - val_loss: 0.4072 - learning_rate: 1.0000e-06
# Epoch 90/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9991 - loss: 0.0160 - val_accuracy: 0.8743 - val_loss: 0.4075 - learning_rate: 1.0000e-06
# Epoch 91/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9975 - loss: 0.0222 - val_accuracy: 0.8689 - val_loss: 0.4073 - learning_rate: 1.0000e-06
# Epoch 92/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9992 - loss: 0.0232 - val_accuracy: 0.8689 - val_loss: 0.4076 - learning_rate: 1.0000e-06
# Epoch 93/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9990 - loss: 0.0139 - val_accuracy: 0.8689 - val_loss: 0.4075 - learning_rate: 1.0000e-06
# Epoch 94/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9985 - loss: 0.0150 - val_accuracy: 0.8689 - val_loss: 0.4073 - learning_rate: 1.0000e-06
# Epoch 95/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9991 - loss: 0.0166 - val_accuracy: 0.8743 - val_loss: 0.4080 - learning_rate: 1.0000e-06
# Epoch 96/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0218 - val_accuracy: 0.8743 - val_loss: 0.4076 - learning_rate: 1.0000e-06
# Epoch 97/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 0.8743 - val_loss: 0.4076 - learning_rate: 1.0000e-06
# Epoch 98/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9993 - loss: 0.0130 - val_accuracy: 0.8743 - val_loss: 0.4076 - learning_rate: 1.0000e-06
# Epoch 99/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9975 - loss: 0.0203 - val_accuracy: 0.8743 - val_loss: 0.4076 - learning_rate: 1.0000e-06
# Epoch 100/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.8743 - val_loss: 0.4068 - learning_rate: 1.0000e-06
# Epoch 101/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.8743 - val_loss: 0.4071 - learning_rate: 1.0000e-06
# Epoch 102/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.8689 - val_loss: 0.4067 - learning_rate: 1.0000e-06
# Epoch 103/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9987 - loss: 0.0220 - val_accuracy: 0.8743 - val_loss: 0.4068 - learning_rate: 1.0000e-06
# Epoch 104/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0192 - val_accuracy: 0.8743 - val_loss: 0.4069 - learning_rate: 1.0000e-06
# Epoch 105/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.8743 - val_loss: 0.4071 - learning_rate: 1.0000e-06
# Epoch 106/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9992 - loss: 0.0157 - val_accuracy: 0.8743 - val_loss: 0.4074 - learning_rate: 1.0000e-06
# Epoch 107/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9997 - loss: 0.0172 - val_accuracy: 0.8743 - val_loss: 0.4072 - learning_rate: 1.0000e-06
# Epoch 108/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9984 - loss: 0.0196 - val_accuracy: 0.8743 - val_loss: 0.4069 - learning_rate: 1.0000e-06
# Epoch 109/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9995 - loss: 0.0118 - val_accuracy: 0.8743 - val_loss: 0.4067 - learning_rate: 1.0000e-06
# Epoch 110/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.8743 - val_loss: 0.4071 - learning_rate: 1.0000e-06
# Epoch 111/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9998 - loss: 0.0213 - val_accuracy: 0.8743 - val_loss: 0.4067 - learning_rate: 1.0000e-06
# Epoch 112/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9984 - loss: 0.0206 - val_accuracy: 0.8743 - val_loss: 0.4076 - learning_rate: 1.0000e-06
# Epoch 113/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9973 - loss: 0.0249 - val_accuracy: 0.8743 - val_loss: 0.4091 - learning_rate: 1.0000e-06
# Epoch 114/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9979 - loss: 0.0253 - val_accuracy: 0.8743 - val_loss: 0.4090 - learning_rate: 1.0000e-06
# Epoch 115/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.8743 - val_loss: 0.4089 - learning_rate: 1.0000e-06
# Epoch 116/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.8743 - val_loss: 0.4092 - learning_rate: 1.0000e-06
# Epoch 117/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.8743 - val_loss: 0.4084 - learning_rate: 1.0000e-06
# Epoch 118/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.8743 - val_loss: 0.4086 - learning_rate: 1.0000e-06
# Epoch 119/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9979 - loss: 0.0181 - val_accuracy: 0.8743 - val_loss: 0.4089 - learning_rate: 1.0000e-06
# Epoch 120/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.8743 - val_loss: 0.4083 - learning_rate: 1.0000e-06
# Epoch 121/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0222 - val_accuracy: 0.8743 - val_loss: 0.4083 - learning_rate: 1.0000e-06
# Epoch 122/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9986 - loss: 0.0160 - val_accuracy: 0.8743 - val_loss: 0.4083 - learning_rate: 1.0000e-06
# Epoch 123/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9984 - loss: 0.0153 - val_accuracy: 0.8689 - val_loss: 0.4084 - learning_rate: 1.0000e-06
# Epoch 124/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9974 - loss: 0.0192 - val_accuracy: 0.8743 - val_loss: 0.4090 - learning_rate: 1.0000e-06
# Epoch 125/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0222 - val_accuracy: 0.8743 - val_loss: 0.4096 - learning_rate: 1.0000e-06
# Epoch 126/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.8743 - val_loss: 0.4094 - learning_rate: 1.0000e-06
# Epoch 127/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.8743 - val_loss: 0.4094 - learning_rate: 1.0000e-06
# Epoch 128/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.8743 - val_loss: 0.4095 - learning_rate: 1.0000e-06
# Epoch 129/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9989 - loss: 0.0133 - val_accuracy: 0.8743 - val_loss: 0.4104 - learning_rate: 1.0000e-06
# Epoch 130/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9999 - loss: 0.0133 - val_accuracy: 0.8743 - val_loss: 0.4094 - learning_rate: 1.0000e-06
# Epoch 131/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.8743 - val_loss: 0.4096 - learning_rate: 1.0000e-06
# Epoch 132/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 0.8689 - val_loss: 0.4090 - learning_rate: 1.0000e-06
# Epoch 133/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9989 - loss: 0.0156 - val_accuracy: 0.8743 - val_loss: 0.4094 - learning_rate: 1.0000e-06
# Epoch 134/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.8743 - val_loss: 0.4098 - learning_rate: 1.0000e-06
# Epoch 135/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 0.8743 - val_loss: 0.4100 - learning_rate: 1.0000e-06
# Epoch 136/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9993 - loss: 0.0117 - val_accuracy: 0.8743 - val_loss: 0.4113 - learning_rate: 1.0000e-06
# Epoch 137/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9999 - loss: 0.0122 - val_accuracy: 0.8743 - val_loss: 0.4110 - learning_rate: 1.0000e-06
# Epoch 138/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.8743 - val_loss: 0.4097 - learning_rate: 1.0000e-06
# Epoch 139/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 0.8743 - val_loss: 0.4097 - learning_rate: 1.0000e-06
# Epoch 140/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9983 - loss: 0.0170 - val_accuracy: 0.8743 - val_loss: 0.4098 - learning_rate: 1.0000e-06
# Epoch 141/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9985 - loss: 0.0198 - val_accuracy: 0.8743 - val_loss: 0.4097 - learning_rate: 1.0000e-06
# Epoch 142/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9984 - loss: 0.0139 - val_accuracy: 0.8743 - val_loss: 0.4102 - learning_rate: 1.0000e-06
# Epoch 143/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9996 - loss: 0.0121 - val_accuracy: 0.8689 - val_loss: 0.4103 - learning_rate: 1.0000e-06
# Epoch 144/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9989 - loss: 0.0158 - val_accuracy: 0.8743 - val_loss: 0.4112 - learning_rate: 1.0000e-06
# Epoch 145/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9991 - loss: 0.0174 - val_accuracy: 0.8743 - val_loss: 0.4110 - learning_rate: 1.0000e-06
# Epoch 146/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9971 - loss: 0.0199 - val_accuracy: 0.8743 - val_loss: 0.4115 - learning_rate: 1.0000e-06
# Epoch 147/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.8743 - val_loss: 0.4119 - learning_rate: 1.0000e-06
# Epoch 148/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9988 - loss: 0.0139 - val_accuracy: 0.8743 - val_loss: 0.4105 - learning_rate: 1.0000e-06
# Epoch 149/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9990 - loss: 0.0136 - val_accuracy: 0.8689 - val_loss: 0.4102 - learning_rate: 1.0000e-06
# Epoch 150/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9965 - loss: 0.0208 - val_accuracy: 0.8689 - val_loss: 0.4104 - learning_rate: 1.0000e-06
# Epoch 151/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9993 - loss: 0.0154 - val_accuracy: 0.8689 - val_loss: 0.4108 - learning_rate: 1.0000e-06
# Epoch 152/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.8743 - val_loss: 0.4110 - learning_rate: 1.0000e-06
# Epoch 153/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0214 - val_accuracy: 0.8689 - val_loss: 0.4108 - learning_rate: 1.0000e-06
# Epoch 154/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 0.8743 - val_loss: 0.4112 - learning_rate: 1.0000e-06
# Epoch 155/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9980 - loss: 0.0128 - val_accuracy: 0.8743 - val_loss: 0.4106 - learning_rate: 1.0000e-06
# Epoch 156/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0208 - val_accuracy: 0.8743 - val_loss: 0.4105 - learning_rate: 1.0000e-06
# Epoch 157/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.8743 - val_loss: 0.4095 - learning_rate: 1.0000e-06
# Epoch 158/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 0.8743 - val_loss: 0.4095 - learning_rate: 1.0000e-06
# Epoch 159/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9992 - loss: 0.0191 - val_accuracy: 0.8743 - val_loss: 0.4100 - learning_rate: 1.0000e-06
# Epoch 160/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9991 - loss: 0.0141 - val_accuracy: 0.8743 - val_loss: 0.4098 - learning_rate: 1.0000e-06
# Epoch 161/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9976 - loss: 0.0184 - val_accuracy: 0.8689 - val_loss: 0.4090 - learning_rate: 1.0000e-06
# Epoch 162/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9984 - loss: 0.0151 - val_accuracy: 0.8743 - val_loss: 0.4092 - learning_rate: 1.0000e-06
# Epoch 163/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9990 - loss: 0.0148 - val_accuracy: 0.8689 - val_loss: 0.4096 - learning_rate: 1.0000e-06
# Epoch 164/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 0.8743 - val_loss: 0.4100 - learning_rate: 1.0000e-06
# Epoch 165/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9993 - loss: 0.0171 - val_accuracy: 0.8743 - val_loss: 0.4108 - learning_rate: 1.0000e-06
# Epoch 166/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9977 - loss: 0.0218 - val_accuracy: 0.8689 - val_loss: 0.4099 - learning_rate: 1.0000e-06
# Epoch 167/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9994 - loss: 0.0138 - val_accuracy: 0.8743 - val_loss: 0.4108 - learning_rate: 1.0000e-06
# Epoch 168/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 0.8743 - val_loss: 0.4115 - learning_rate: 1.0000e-06
# Epoch 169/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9985 - loss: 0.0138 - val_accuracy: 0.8743 - val_loss: 0.4112 - learning_rate: 1.0000e-06
# Epoch 170/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9983 - loss: 0.0167 - val_accuracy: 0.8743 - val_loss: 0.4114 - learning_rate: 1.0000e-06
# Epoch 171/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.8743 - val_loss: 0.4108 - learning_rate: 1.0000e-06
# Epoch 172/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.8689 - val_loss: 0.4106 - learning_rate: 1.0000e-06
# Epoch 173/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9982 - loss: 0.0143 - val_accuracy: 0.8743 - val_loss: 0.4110 - learning_rate: 1.0000e-06
# Epoch 174/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.8743 - val_loss: 0.4115 - learning_rate: 1.0000e-06
# Epoch 175/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9976 - loss: 0.0180 - val_accuracy: 0.8689 - val_loss: 0.4102 - learning_rate: 1.0000e-06
# Epoch 176/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9984 - loss: 0.0216 - val_accuracy: 0.8743 - val_loss: 0.4107 - learning_rate: 1.0000e-06
# Epoch 177/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.8743 - val_loss: 0.4111 - learning_rate: 1.0000e-06
# Epoch 178/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9976 - loss: 0.0164 - val_accuracy: 0.8743 - val_loss: 0.4119 - learning_rate: 1.0000e-06
# Epoch 179/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 0.8689 - val_loss: 0.4111 - learning_rate: 1.0000e-06
# Epoch 180/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9987 - loss: 0.0156 - val_accuracy: 0.8743 - val_loss: 0.4114 - learning_rate: 1.0000e-06
# Epoch 181/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9995 - loss: 0.0113 - val_accuracy: 0.8743 - val_loss: 0.4106 - learning_rate: 1.0000e-06
# Epoch 182/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9982 - loss: 0.0142 - val_accuracy: 0.8743 - val_loss: 0.4103 - learning_rate: 1.0000e-06
# Epoch 183/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9994 - loss: 0.0163 - val_accuracy: 0.8743 - val_loss: 0.4111 - learning_rate: 1.0000e-06
# Epoch 184/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9989 - loss: 0.0130 - val_accuracy: 0.8743 - val_loss: 0.4112 - learning_rate: 1.0000e-06
# Epoch 185/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.8743 - val_loss: 0.4106 - learning_rate: 1.0000e-06
# Epoch 186/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9984 - loss: 0.0143 - val_accuracy: 0.8743 - val_loss: 0.4115 - learning_rate: 1.0000e-06
# Epoch 187/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.8743 - val_loss: 0.4106 - learning_rate: 1.0000e-06
# Epoch 188/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9952 - loss: 0.0170 - val_accuracy: 0.8743 - val_loss: 0.4104 - learning_rate: 1.0000e-06
# Epoch 189/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9996 - loss: 0.0146 - val_accuracy: 0.8743 - val_loss: 0.4108 - learning_rate: 1.0000e-06
# Epoch 190/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9985 - loss: 0.0156 - val_accuracy: 0.8743 - val_loss: 0.4108 - learning_rate: 1.0000e-06
# Epoch 191/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9997 - loss: 0.0172 - val_accuracy: 0.8743 - val_loss: 0.4113 - learning_rate: 1.0000e-06
# Epoch 192/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9954 - loss: 0.0188 - val_accuracy: 0.8743 - val_loss: 0.4118 - learning_rate: 1.0000e-06
# Epoch 193/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9993 - loss: 0.0143 - val_accuracy: 0.8743 - val_loss: 0.4120 - learning_rate: 1.0000e-06
# Epoch 194/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0176 - val_accuracy: 0.8743 - val_loss: 0.4118 - learning_rate: 1.0000e-06
# Epoch 195/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9954 - loss: 0.0179 - val_accuracy: 0.8743 - val_loss: 0.4119 - learning_rate: 1.0000e-06
# Epoch 196/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.8743 - val_loss: 0.4121 - learning_rate: 1.0000e-06
# Epoch 197/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 0.8743 - val_loss: 0.4124 - learning_rate: 1.0000e-06
# Epoch 198/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.8743 - val_loss: 0.4124 - learning_rate: 1.0000e-06
# Epoch 199/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.8743 - val_loss: 0.4128 - learning_rate: 1.0000e-06
# Epoch 200/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.8743 - val_loss: 0.4129 - learning_rate: 1.0000e-06
# Epoch 201/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9978 - loss: 0.0118 - val_accuracy: 0.8743 - val_loss: 0.4125 - learning_rate: 1.0000e-06
# Epoch 202/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9972 - loss: 0.0156 - val_accuracy: 0.8743 - val_loss: 0.4128 - learning_rate: 1.0000e-06
# Epoch 203/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9995 - loss: 0.0127 - val_accuracy: 0.8743 - val_loss: 0.4132 - learning_rate: 1.0000e-06
# Epoch 204/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9981 - loss: 0.0155 - val_accuracy: 0.8743 - val_loss: 0.4143 - learning_rate: 1.0000e-06
# Epoch 205/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 0.8743 - val_loss: 0.4141 - learning_rate: 1.0000e-06
# Epoch 206/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.8743 - val_loss: 0.4137 - learning_rate: 1.0000e-06
# Epoch 207/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.8743 - val_loss: 0.4129 - learning_rate: 1.0000e-06
# Epoch 208/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9983 - loss: 0.0129 - val_accuracy: 0.8743 - val_loss: 0.4135 - learning_rate: 1.0000e-06
# Epoch 209/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9952 - loss: 0.0275 - val_accuracy: 0.8689 - val_loss: 0.4135 - learning_rate: 1.0000e-06
# Epoch 210/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 0.8689 - val_loss: 0.4138 - learning_rate: 1.0000e-06
# Epoch 211/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9995 - loss: 0.0119 - val_accuracy: 0.8743 - val_loss: 0.4147 - learning_rate: 1.0000e-06
# Epoch 212/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9999 - loss: 0.0164 - val_accuracy: 0.8743 - val_loss: 0.4145 - learning_rate: 1.0000e-06
# Epoch 213/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9968 - loss: 0.0154 - val_accuracy: 0.8743 - val_loss: 0.4154 - learning_rate: 1.0000e-06
# Epoch 214/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.8689 - val_loss: 0.4147 - learning_rate: 1.0000e-06
# Epoch 215/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9993 - loss: 0.0138 - val_accuracy: 0.8743 - val_loss: 0.4155 - learning_rate: 1.0000e-06
# Epoch 216/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.8689 - val_loss: 0.4160 - learning_rate: 1.0000e-06
# Epoch 217/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9998 - loss: 0.0135 - val_accuracy: 0.8743 - val_loss: 0.4159 - learning_rate: 1.0000e-06
# Epoch 218/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.8743 - val_loss: 0.4157 - learning_rate: 1.0000e-06
# Epoch 219/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9995 - loss: 0.0113 - val_accuracy: 0.8743 - val_loss: 0.4165 - learning_rate: 1.0000e-06
# Epoch 220/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9966 - loss: 0.0167 - val_accuracy: 0.8743 - val_loss: 0.4165 - learning_rate: 1.0000e-06
# Epoch 221/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9944 - loss: 0.0252 - val_accuracy: 0.8743 - val_loss: 0.4175 - learning_rate: 1.0000e-06
# Epoch 222/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.8743 - val_loss: 0.4167 - learning_rate: 1.0000e-06
# Epoch 223/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9989 - loss: 0.0171 - val_accuracy: 0.8743 - val_loss: 0.4164 - learning_rate: 1.0000e-06
# Epoch 224/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9985 - loss: 0.0134 - val_accuracy: 0.8743 - val_loss: 0.4165 - learning_rate: 1.0000e-06
# Epoch 225/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.8743 - val_loss: 0.4166 - learning_rate: 1.0000e-06
# Epoch 226/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.8743 - val_loss: 0.4167 - learning_rate: 1.0000e-06
# Epoch 227/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9963 - loss: 0.0222 - val_accuracy: 0.8743 - val_loss: 0.4180 - learning_rate: 1.0000e-06
# Epoch 228/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9968 - loss: 0.0130 - val_accuracy: 0.8743 - val_loss: 0.4175 - learning_rate: 1.0000e-06
# Epoch 229/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.8743 - val_loss: 0.4174 - learning_rate: 1.0000e-06
# Epoch 230/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9973 - loss: 0.0165 - val_accuracy: 0.8743 - val_loss: 0.4173 - learning_rate: 1.0000e-06
# Epoch 231/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.8743 - val_loss: 0.4173 - learning_rate: 1.0000e-06
# Epoch 232/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9965 - loss: 0.0210 - val_accuracy: 0.8743 - val_loss: 0.4168 - learning_rate: 1.0000e-06
# Epoch 233/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9993 - loss: 0.0131 - val_accuracy: 0.8743 - val_loss: 0.4163 - learning_rate: 1.0000e-06
# Epoch 234/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9952 - loss: 0.0249 - val_accuracy: 0.8743 - val_loss: 0.4163 - learning_rate: 1.0000e-06
# Epoch 235/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9947 - loss: 0.0191 - val_accuracy: 0.8743 - val_loss: 0.4172 - learning_rate: 1.0000e-06
# Epoch 236/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.8743 - val_loss: 0.4172 - learning_rate: 1.0000e-06
# Epoch 237/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.8743 - val_loss: 0.4181 - learning_rate: 1.0000e-06
# Epoch 238/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.8743 - val_loss: 0.4180 - learning_rate: 1.0000e-06
# Epoch 239/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.8689 - val_loss: 0.4179 - learning_rate: 1.0000e-06
# Epoch 240/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9998 - loss: 0.0111 - val_accuracy: 0.8743 - val_loss: 0.4182 - learning_rate: 1.0000e-06
# Epoch 241/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9991 - loss: 0.0154 - val_accuracy: 0.8743 - val_loss: 0.4191 - learning_rate: 1.0000e-06
# Epoch 242/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.8743 - val_loss: 0.4192 - learning_rate: 1.0000e-06
# Epoch 243/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.8743 - val_loss: 0.4183 - learning_rate: 1.0000e-06
# Epoch 244/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9977 - loss: 0.0134 - val_accuracy: 0.8743 - val_loss: 0.4185 - learning_rate: 1.0000e-06
# Epoch 245/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9951 - loss: 0.0208 - val_accuracy: 0.8743 - val_loss: 0.4186 - learning_rate: 1.0000e-06
# Epoch 246/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.8743 - val_loss: 0.4180 - learning_rate: 1.0000e-06
# Epoch 247/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9991 - loss: 0.0151 - val_accuracy: 0.8743 - val_loss: 0.4187 - learning_rate: 1.0000e-06
# Epoch 248/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.8743 - val_loss: 0.4180 - learning_rate: 1.0000e-06
# Epoch 249/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.8743 - val_loss: 0.4177 - learning_rate: 1.0000e-06
# Epoch 250/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9991 - loss: 0.0118 - val_accuracy: 0.8743 - val_loss: 0.4176 - learning_rate: 1.0000e-06
# Epoch 251/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.8743 - val_loss: 0.4181 - learning_rate: 1.0000e-06
# Epoch 252/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9993 - loss: 0.0113 - val_accuracy: 0.8743 - val_loss: 0.4180 - learning_rate: 1.0000e-06
# Epoch 253/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9971 - loss: 0.0211 - val_accuracy: 0.8743 - val_loss: 0.4182 - learning_rate: 1.0000e-06
# Epoch 254/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.8743 - val_loss: 0.4187 - learning_rate: 1.0000e-06
# Epoch 255/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.8743 - val_loss: 0.4186 - learning_rate: 1.0000e-06
# Epoch 256/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9920 - loss: 0.0233 - val_accuracy: 0.8743 - val_loss: 0.4197 - learning_rate: 1.0000e-06
# Epoch 257/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9974 - loss: 0.0141 - val_accuracy: 0.8743 - val_loss: 0.4199 - learning_rate: 1.0000e-06
# Epoch 258/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9979 - loss: 0.0134 - val_accuracy: 0.8743 - val_loss: 0.4203 - learning_rate: 1.0000e-06
# Epoch 259/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.8743 - val_loss: 0.4199 - learning_rate: 1.0000e-06
# Epoch 260/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.8743 - val_loss: 0.4189 - learning_rate: 1.0000e-06
# Epoch 261/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.8743 - val_loss: 0.4198 - learning_rate: 1.0000e-06
# Epoch 262/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.8743 - val_loss: 0.4197 - learning_rate: 1.0000e-06
# Epoch 263/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9978 - loss: 0.0176 - val_accuracy: 0.8743 - val_loss: 0.4183 - learning_rate: 1.0000e-06
# Epoch 264/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9994 - loss: 0.0111 - val_accuracy: 0.8743 - val_loss: 0.4179 - learning_rate: 1.0000e-06
# Epoch 265/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9956 - loss: 0.0124 - val_accuracy: 0.8743 - val_loss: 0.4182 - learning_rate: 1.0000e-06
# Epoch 266/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.8743 - val_loss: 0.4183 - learning_rate: 1.0000e-06
# Epoch 267/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.8743 - val_loss: 0.4184 - learning_rate: 1.0000e-06
# Epoch 268/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.8743 - val_loss: 0.4193 - learning_rate: 1.0000e-06
# Epoch 269/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9999 - loss: 0.0103 - val_accuracy: 0.8743 - val_loss: 0.4186 - learning_rate: 1.0000e-06
# Epoch 270/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9981 - loss: 0.0129 - val_accuracy: 0.8743 - val_loss: 0.4175 - learning_rate: 1.0000e-06
# Epoch 271/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9999 - loss: 0.0104 - val_accuracy: 0.8743 - val_loss: 0.4172 - learning_rate: 1.0000e-06
# Epoch 272/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9974 - loss: 0.0157 - val_accuracy: 0.8743 - val_loss: 0.4176 - learning_rate: 1.0000e-06
# Epoch 273/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9996 - loss: 0.0116 - val_accuracy: 0.8743 - val_loss: 0.4174 - learning_rate: 1.0000e-06
# Epoch 274/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.8743 - val_loss: 0.4174 - learning_rate: 1.0000e-06
# Epoch 275/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.8743 - val_loss: 0.4174 - learning_rate: 1.0000e-06
# Epoch 276/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.8743 - val_loss: 0.4180 - learning_rate: 1.0000e-06
# Epoch 277/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9984 - loss: 0.0116 - val_accuracy: 0.8743 - val_loss: 0.4183 - learning_rate: 1.0000e-06
# Epoch 278/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.8743 - val_loss: 0.4172 - learning_rate: 1.0000e-06
# Epoch 279/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.8743 - val_loss: 0.4177 - learning_rate: 1.0000e-06
# Epoch 280/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9959 - loss: 0.0174 - val_accuracy: 0.8743 - val_loss: 0.4178 - learning_rate: 1.0000e-06
# Epoch 281/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8689 - val_loss: 0.4172 - learning_rate: 1.0000e-06
# Epoch 282/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.8743 - val_loss: 0.4181 - learning_rate: 1.0000e-06
# Epoch 283/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.8743 - val_loss: 0.4182 - learning_rate: 1.0000e-06
# Epoch 284/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.8743 - val_loss: 0.4188 - learning_rate: 1.0000e-06
# Epoch 285/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9996 - loss: 0.0115 - val_accuracy: 0.8743 - val_loss: 0.4184 - learning_rate: 1.0000e-06
# Epoch 286/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9980 - loss: 0.0180 - val_accuracy: 0.8743 - val_loss: 0.4190 - learning_rate: 1.0000e-06
# Epoch 287/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.8743 - val_loss: 0.4186 - learning_rate: 1.0000e-06
# Epoch 288/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.8743 - val_loss: 0.4182 - learning_rate: 1.0000e-06
# Epoch 289/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9987 - loss: 0.0109 - val_accuracy: 0.8743 - val_loss: 0.4182 - learning_rate: 1.0000e-06
# Epoch 290/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.8743 - val_loss: 0.4184 - learning_rate: 1.0000e-06
# Epoch 291/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 0.8743 - val_loss: 0.4191 - learning_rate: 1.0000e-06
# Epoch 292/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9994 - loss: 0.0121 - val_accuracy: 0.8743 - val_loss: 0.4196 - learning_rate: 1.0000e-06
# Epoch 293/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9996 - loss: 0.0112 - val_accuracy: 0.8743 - val_loss: 0.4194 - learning_rate: 1.0000e-06
# Epoch 294/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9938 - loss: 0.0267 - val_accuracy: 0.8743 - val_loss: 0.4212 - learning_rate: 1.0000e-06
# Epoch 295/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9928 - loss: 0.0191 - val_accuracy: 0.8689 - val_loss: 0.4217 - learning_rate: 1.0000e-06
# Epoch 296/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8743 - val_loss: 0.4216 - learning_rate: 1.0000e-06
# Epoch 297/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.8689 - val_loss: 0.4216 - learning_rate: 1.0000e-06
# Epoch 298/500
# ...
# Epoch 401/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.8689 - val_loss: 0.4321 - learning_rate: 1.0000e-06
# Epoch 402/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.8689 - val_loss: 0.4313 - learning_rate: 1.0000e-06
# Epoch 403/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.8743 - val_loss: 0.4311 - learning_rate: 1.0000e-06
# Epoch 404/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8743 - val_loss: 0.4320 - learning_rate: 1.0000e-06
# Epoch 405/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8689 - val_loss: 0.4314 - learning_rate: 1.0000e-06
# Epoch 406/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9945 - loss: 0.0207 - val_accuracy: 0.8743 - val_loss: 0.4328 - learning_rate: 1.0000e-06
# Epoch 407/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.8743 - val_loss: 0.4330 - learning_rate: 1.0000e-06
# Epoch 408/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.8743 - val_loss: 0.4331 - learning_rate: 1.0000e-06
# Epoch 409/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9986 - loss: 0.0120 - val_accuracy: 0.8743 - val_loss: 0.4318 - learning_rate: 1.0000e-06
# Epoch 410/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9946 - loss: 0.0154 - val_accuracy: 0.8743 - val_loss: 0.4315 - learning_rate: 1.0000e-06
# Epoch 411/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.8743 - val_loss: 0.4320 - learning_rate: 1.0000e-06
# Epoch 412/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.8689 - val_loss: 0.4317 - learning_rate: 1.0000e-06
# Epoch 413/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8689 - val_loss: 0.4319 - learning_rate: 1.0000e-06
# Epoch 414/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.8743 - val_loss: 0.4320 - learning_rate: 1.0000e-06
# Epoch 415/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.8743 - val_loss: 0.4340 - learning_rate: 1.0000e-06
# Epoch 416/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.8743 - val_loss: 0.4345 - learning_rate: 1.0000e-06
# Epoch 417/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.8743 - val_loss: 0.4347 - learning_rate: 1.0000e-06
# Epoch 418/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.8743 - val_loss: 0.4341 - learning_rate: 1.0000e-06
# Epoch 419/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.8743 - val_loss: 0.4346 - learning_rate: 1.0000e-06
# Epoch 420/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9995 - loss: 0.0149 - val_accuracy: 0.8743 - val_loss: 0.4356 - learning_rate: 1.0000e-06
# Epoch 421/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9996 - loss: 0.0070 - val_accuracy: 0.8743 - val_loss: 0.4348 - learning_rate: 1.0000e-06
# Epoch 422/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.8743 - val_loss: 0.4351 - learning_rate: 1.0000e-06
# Epoch 423/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.8743 - val_loss: 0.4349 - learning_rate: 1.0000e-06
# Epoch 424/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8743 - val_loss: 0.4346 - learning_rate: 1.0000e-06
# Epoch 425/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.8743 - val_loss: 0.4337 - learning_rate: 1.0000e-06
# Epoch 426/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.8689 - val_loss: 0.4337 - learning_rate: 1.0000e-06
# Epoch 427/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.8689 - val_loss: 0.4341 - learning_rate: 1.0000e-06
# Epoch 428/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.8689 - val_loss: 0.4353 - learning_rate: 1.0000e-06
# Epoch 429/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9936 - loss: 0.0195 - val_accuracy: 0.8689 - val_loss: 0.4365 - learning_rate: 1.0000e-06
# Epoch 430/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8689 - val_loss: 0.4367 - learning_rate: 1.0000e-06
# Epoch 431/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9988 - loss: 0.0111 - val_accuracy: 0.8689 - val_loss: 0.4369 - learning_rate: 1.0000e-06
# Epoch 432/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8689 - val_loss: 0.4372 - learning_rate: 1.0000e-06
# Epoch 433/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.8689 - val_loss: 0.4361 - learning_rate: 1.0000e-06
# Epoch 434/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8689 - val_loss: 0.4360 - learning_rate: 1.0000e-06
# Epoch 435/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8689 - val_loss: 0.4363 - learning_rate: 1.0000e-06
# Epoch 436/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.8689 - val_loss: 0.4368 - learning_rate: 1.0000e-06
# Epoch 437/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.8689 - val_loss: 0.4369 - learning_rate: 1.0000e-06
# Epoch 438/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9994 - loss: 0.0124 - val_accuracy: 0.8689 - val_loss: 0.4364 - learning_rate: 1.0000e-06
# Epoch 439/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.8689 - val_loss: 0.4372 - learning_rate: 1.0000e-06
# Epoch 440/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9992 - loss: 0.0108 - val_accuracy: 0.8689 - val_loss: 0.4379 - learning_rate: 1.0000e-06
# Epoch 441/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.8689 - val_loss: 0.4379 - learning_rate: 1.0000e-06
# Epoch 442/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8689 - val_loss: 0.4377 - learning_rate: 1.0000e-06
# Epoch 443/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9992 - loss: 0.0128 - val_accuracy: 0.8689 - val_loss: 0.4384 - learning_rate: 1.0000e-06
# Epoch 444/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9988 - loss: 0.0122 - val_accuracy: 0.8689 - val_loss: 0.4379 - learning_rate: 1.0000e-06
# Epoch 445/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.8689 - val_loss: 0.4378 - learning_rate: 1.0000e-06
# Epoch 446/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9937 - loss: 0.0204 - val_accuracy: 0.8689 - val_loss: 0.4389 - learning_rate: 1.0000e-06
# Epoch 447/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.8689 - val_loss: 0.4376 - learning_rate: 1.0000e-06
# Epoch 448/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.8689 - val_loss: 0.4376 - learning_rate: 1.0000e-06
# Epoch 449/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8689 - val_loss: 0.4375 - learning_rate: 1.0000e-06
# Epoch 450/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.8689 - val_loss: 0.4379 - learning_rate: 1.0000e-06
# Epoch 451/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9954 - loss: 0.0159 - val_accuracy: 0.8689 - val_loss: 0.4380 - learning_rate: 1.0000e-06
# Epoch 452/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9983 - loss: 0.0150 - val_accuracy: 0.8689 - val_loss: 0.4381 - learning_rate: 1.0000e-06
# Epoch 453/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.8689 - val_loss: 0.4375 - learning_rate: 1.0000e-06
# Epoch 454/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9994 - loss: 0.0104 - val_accuracy: 0.8689 - val_loss: 0.4391 - learning_rate: 1.0000e-06
# Epoch 455/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9957 - loss: 0.0162 - val_accuracy: 0.8689 - val_loss: 0.4404 - learning_rate: 1.0000e-06
# Epoch 456/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9969 - loss: 0.0113 - val_accuracy: 0.8689 - val_loss: 0.4390 - learning_rate: 1.0000e-06
# Epoch 457/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9941 - loss: 0.0154 - val_accuracy: 0.8689 - val_loss: 0.4392 - learning_rate: 1.0000e-06
# Epoch 458/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.8689 - val_loss: 0.4381 - learning_rate: 1.0000e-06
# Epoch 459/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.8689 - val_loss: 0.4390 - learning_rate: 1.0000e-06
# Epoch 460/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.8689 - val_loss: 0.4383 - learning_rate: 1.0000e-06
# Epoch 461/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.8689 - val_loss: 0.4381 - learning_rate: 1.0000e-06
# Epoch 462/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9996 - loss: 0.0088 - val_accuracy: 0.8689 - val_loss: 0.4386 - learning_rate: 1.0000e-06
# Epoch 463/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9998 - loss: 0.0083 - val_accuracy: 0.8689 - val_loss: 0.4384 - learning_rate: 1.0000e-06
# Epoch 464/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9996 - loss: 0.0087 - val_accuracy: 0.8689 - val_loss: 0.4392 - learning_rate: 1.0000e-06
# Epoch 465/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9993 - loss: 0.0101 - val_accuracy: 0.8689 - val_loss: 0.4384 - learning_rate: 1.0000e-06
# Epoch 466/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.8689 - val_loss: 0.4396 - learning_rate: 1.0000e-06
# Epoch 467/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.8689 - val_loss: 0.4405 - learning_rate: 1.0000e-06
# Epoch 468/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.8689 - val_loss: 0.4399 - learning_rate: 1.0000e-06
# Epoch 469/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.8689 - val_loss: 0.4406 - learning_rate: 1.0000e-06
# Epoch 470/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.8689 - val_loss: 0.4392 - learning_rate: 1.0000e-06
# Epoch 471/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.8689 - val_loss: 0.4396 - learning_rate: 1.0000e-06
# Epoch 472/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8689 - val_loss: 0.4395 - learning_rate: 1.0000e-06
# Epoch 473/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9993 - loss: 0.0113 - val_accuracy: 0.8689 - val_loss: 0.4402 - learning_rate: 1.0000e-06
# Epoch 474/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9994 - loss: 0.0119 - val_accuracy: 0.8689 - val_loss: 0.4392 - learning_rate: 1.0000e-06
# Epoch 475/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.8743 - val_loss: 0.4402 - learning_rate: 1.0000e-06
# Epoch 476/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9996 - loss: 0.0103 - val_accuracy: 0.8689 - val_loss: 0.4401 - learning_rate: 1.0000e-06
# Epoch 477/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.8743 - val_loss: 0.4406 - learning_rate: 1.0000e-06
# Epoch 478/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8743 - val_loss: 0.4413 - learning_rate: 1.0000e-06
# Epoch 479/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.8689 - val_loss: 0.4418 - learning_rate: 1.0000e-06
# Epoch 480/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.8689 - val_loss: 0.4424 - learning_rate: 1.0000e-06
# Epoch 481/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8689 - val_loss: 0.4424 - learning_rate: 1.0000e-06
# Epoch 482/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8689 - val_loss: 0.4425 - learning_rate: 1.0000e-06
# Epoch 483/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8689 - val_loss: 0.4423 - learning_rate: 1.0000e-06
# Epoch 484/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.8689 - val_loss: 0.4418 - learning_rate: 1.0000e-06
# Epoch 485/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8689 - val_loss: 0.4415 - learning_rate: 1.0000e-06
# Epoch 486/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.8689 - val_loss: 0.4411 - learning_rate: 1.0000e-06
# Epoch 487/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 0.8689 - val_loss: 0.4403 - learning_rate: 1.0000e-06
# Epoch 488/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8689 - val_loss: 0.4413 - learning_rate: 1.0000e-06
# Epoch 489/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9995 - loss: 0.0079 - val_accuracy: 0.8743 - val_loss: 0.4404 - learning_rate: 1.0000e-06
# Epoch 490/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.8743 - val_loss: 0.4413 - learning_rate: 1.0000e-06
# Epoch 491/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.8743 - val_loss: 0.4407 - learning_rate: 1.0000e-06
# Epoch 492/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.8689 - val_loss: 0.4419 - learning_rate: 1.0000e-06
# Epoch 493/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.8689 - val_loss: 0.4418 - learning_rate: 1.0000e-06
# Epoch 494/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.8689 - val_loss: 0.4419 - learning_rate: 1.0000e-06
# Epoch 495/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8689 - val_loss: 0.4416 - learning_rate: 1.0000e-06
# Epoch 496/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.8689 - val_loss: 0.4425 - learning_rate: 1.0000e-06
# Epoch 497/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.8689 - val_loss: 0.4420 - learning_rate: 1.0000e-06
# Epoch 498/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.8689 - val_loss: 0.4415 - learning_rate: 1.0000e-06
# Epoch 499/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.8689 - val_loss: 0.4416 - learning_rate: 1.0000e-06
# Epoch 500/500
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.8689 - val_loss: 0.4427 - learning_rate: 1.0000e-06
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.8942 - loss: 0.4765
# Test Loss: 0.4978, Test Accuracy: 0.8808

# %%
plot_learning_curves(history)

# %%
plot_confusion_matrix(model, test_generator)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step

# %%
class_labels = ['covid19', 'normal', 'pneumonia']
y_true = []
y_probs = []

for x_batch, y_batch in test_generator:
    preds = model.predict(x_batch)
    y_probs.extend(preds)
    y_true.extend(np.argmax(y_batch, axis=1)) 

    if len(y_true) >= test_generator.samples:
        break

y_true = np.array(y_true)
y_probs = np.array(y_probs)

plot_multiclass_roc_pr(y_true, y_probs, class_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step

# %%
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
tsne_results = tsne.fit_transform(y_probs)

class_names = list(test_generator.class_indices.keys())

plt.figure(figsize=(8, 6))
for i in range(len(class_names)):
    indices = y_true == i
    plt.scatter(tsne_results[indices, 0], tsne_results[indices, 1], label=class_names[i], alpha=0.6)

plt.title("t-SNE Visualization of Model Predictions")
plt.xlabel("t-SNE Dimension 1")
plt.ylabel("t-SNE Dimension 2")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Explanatory Techniques

# %% [markdown]
# ### LIME

# %%
try:
    image_paths = [
        (os.path.join(test_dir, 'covid19', os.listdir(os.path.join(test_dir, 'covid19'))[4]), 'covid19'),
        (os.path.join(test_dir, 'pneumonia', os.listdir(os.path.join(test_dir, 'pneumonia'))[4]), 'pneumonia'),
        (os.path.join(test_dir, 'normal', os.listdir(os.path.join(test_dir, 'normal'))[4]), 'normal')
    ]
    explain_with_lime(model, image_paths)
except Exception as e:
    print(f"Error loading sample images: {e}")
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Image: /kaggle/input/feature-selelcted-dataset/test/covid19/image_108.png
# Predicted probabilities: {'covid19': 0.9926415, 'normal': 3.971069e-06, 'pneumonia': 0.0073545086}
#   0%|          | 0/500 [00:00<?, ?it/s]
# Image: /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_138.png
# Predicted probabilities: {'covid19': 0.0007331855, 'normal': 0.001035625, 'pneumonia': 0.99823123}
#   0%|          | 0/500 [00:00<?, ?it/s]
# Image: /kaggle/input/feature-selelcted-dataset/test/normal/image_133.png
# Predicted probabilities: {'covid19': 0.00021674714, 'normal': 0.99973947, 'pneumonia': 4.3766107e-05}

# %% [markdown]
# ### GRAD-CAM

# %%
for img_path, class_label in image_paths:
    apply_grad_cam(
        model=model,
        image_path=img_path,
        class_label=class_label,
        class_labels=class_labels,
        last_conv_layer_name='conv_layer',
        save_dir='.'
    )
# Out:
# Processing image: /kaggle/input/feature-selelcted-dataset/test/covid19/image_108.png
# Sample image shape: (224, 224, 3)
# Sample image min/max: 0.0 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted class: covid19
# Predictions: [9.9264151e-01 3.9710690e-06 7.3545086e-03]
# Heatmap shape: (224, 224)
# Heatmap min/max: 0.0 1.0
# Plot saved to: /kaggle/working/grad_cam_covid19.png
# Processing image: /kaggle/input/feature-selelcted-dataset/test/pneumonia/image_138.png
# Sample image shape: (224, 224, 3)
# Sample image min/max: 0.0 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted class: pneumonia
# Predictions: [7.3318550e-04 1.0356250e-03 9.9823123e-01]
# Heatmap shape: (224, 224)
# Heatmap min/max: 0.0 1.0
# Plot saved to: /kaggle/working/grad_cam_pneumonia.png
# Processing image: /kaggle/input/feature-selelcted-dataset/test/normal/image_133.png
# Sample image shape: (224, 224, 3)
# Sample image min/max: 0.0 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted class: normal
# Predictions: [2.1674714e-04 9.9973947e-01 4.3766107e-05]
# Heatmap shape: (224, 224)
# Heatmap min/max: 0.0 1.0
# Plot saved to: /kaggle/working/grad_cam_normal.png

# %% [markdown]
# ### DEEPLIFT

# %%
class_labels = ['covid19', 'normal', 'pneumonia']
label_to_index = {label: idx for idx, label in enumerate(class_labels)}

images = []
labels = []

for path, label_str in image_paths:
    img_normalized, _ = preprocess_image(path)  
    if img_normalized is not None:
        images.append(img_normalized)
        labels.append(label_to_index[label_str])

sample_images = np.array(images)
sample_labels = np.array(labels)

# %%
for i in range(len(sample_images)):
    img = sample_images[i:i+1]
    heatmap, pred_class = deeplift(model, img)
    
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(img[0])
    plt.title(f"True: {class_labels[labels[i]]}, Pred: {class_labels[pred_class]}")
    plt.axis('off')
    
    plt.subplot(1, 2, 2)
    superimposed_img = display_heatmap(img, heatmap)
    plt.imshow(superimposed_img)
    plt.title("DeepLIFT Heatmap")
    plt.axis('off')
    
    plt.show()

# %% [markdown]
# ### permutation Importance

# %%
img_covid = sample_images[0]
img_pneumnia = sample_images[1]
img_normal = sample_images[2]


permutation_importance(img_covid, model, class_index=0, model_name="simple conv", raw_image=img_covid)
permutation_importance(img_pneumnia, model, class_index=1, model_name="simple conv", raw_image=img_pneumnia)
permutation_importance(img_normal, model, class_index=2, model_name="simple conv", raw_image=img_normal)
