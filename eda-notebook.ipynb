# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/merged-dataset/test/pneumonia/image_180.png
# /kaggle/input/merged-dataset/test/pneumonia/image_13.png
# /kaggle/input/merged-dataset/test/pneumonia/image_135.png
# /kaggle/input/merged-dataset/test/pneumonia/image_57.png
# /kaggle/input/merged-dataset/test/pneumonia/image_58.png
# /kaggle/input/merged-dataset/test/pneumonia/image_166.png
# /kaggle/input/merged-dataset/test/pneumonia/image_101.png
# /kaggle/input/merged-dataset/test/pneumonia/image_116.png
# /kaggle/input/merged-dataset/test/pneumonia/image_175.png
# /kaggle/input/merged-dataset/test/pneumonia/image_201.png
# /kaggle/input/merged-dataset/test/pneumonia/image_81.png
# /kaggle/input/merged-dataset/test/pneumonia/image_153.png
# /kaggle/input/merged-dataset/test/pneumonia/image_199.png
# /kaggle/input/merged-dataset/test/pneumonia/image_181.png
# /kaggle/input/merged-dataset/test/pneumonia/image_184.png
# /kaggle/input/merged-dataset/test/pneumonia/image_174.png
# /kaggle/input/merged-dataset/test/pneumonia/image_227.png
# /kaggle/input/merged-dataset/test/pneumonia/image_82.png
# /kaggle/input/merged-dataset/test/pneumonia/image_119.png
# /kaggle/input/merged-dataset/test/pneumonia/image_45.png
# /kaggle/input/merged-dataset/test/pneumonia/image_15.png
# /kaggle/input/merged-dataset/test/pneumonia/image_210.png
# /kaggle/input/merged-dataset/test/pneumonia/image_172.png
# /kaggle/input/merged-dataset/test/pneumonia/image_144.png
# /kaggle/input/merged-dataset/test/pneumonia/image_121.png
# /kaggle/input/merged-dataset/test/pneumonia/image_131.png
# /kaggle/input/merged-dataset/test/pneumonia/image_234.png
# /kaggle/input/merged-dataset/test/pneumonia/image_106.png
# /kaggle/input/merged-dataset/test/pneumonia/image_33.png
# /kaggle/input/merged-dataset/test/pneumonia/image_203.png
# /kaggle/input/merged-dataset/test/pneumonia/image_158.png
# /kaggle/input/merged-dataset/test/pneumonia/image_220.png
# /kaggle/input/merged-dataset/test/pneumonia/image_206.png
# /kaggle/input/merged-dataset/test/pneumonia/image_241.png
# /kaggle/input/merged-dataset/test/pneumonia/image_109.png
# /kaggle/input/merged-dataset/test/pneumonia/image_157.png
# /kaggle/input/merged-dataset/test/pneumonia/image_78.png
# /kaggle/input/merged-dataset/test/pneumonia/image_49.png
# /kaggle/input/merged-dataset/test/pneumonia/image_179.png
# /kaggle/input/merged-dataset/test/pneumonia/image_151.png
# /kaggle/input/merged-dataset/test/pneumonia/image_128.png
# /kaggle/input/merged-dataset/test/pneumonia/image_8.png
# /kaggle/input/merged-dataset/test/pneumonia/image_61.png
# /kaggle/input/merged-dataset/test/pneumonia/image_215.png
# /kaggle/input/merged-dataset/test/pneumonia/image_240.png
# /kaggle/input/merged-dataset/test/pneumonia/image_75.png
# /kaggle/input/merged-dataset/test/pneumonia/image_161.png
# /kaggle/input/merged-dataset/test/pneumonia/image_98.png
# /kaggle/input/merged-dataset/test/normal/image_1.png
# /kaggle/input/merged-dataset/test/normal/image_213.png
# /kaggle/input/merged-dataset/test/normal/image_6.png
# /kaggle/input/merged-dataset/test/normal/image_133.png
# /kaggle/input/merged-dataset/test/normal/image_22.png
# /kaggle/input/merged-dataset/test/normal/image_150.png
# /kaggle/input/merged-dataset/test/normal/image_93.png
# /kaggle/input/merged-dataset/test/normal/image_198.png
# /kaggle/input/merged-dataset/test/normal/image_156.png
# /kaggle/input/merged-dataset/test/normal/image_137.png
# /kaggle/input/merged-dataset/test/normal/image_191.png
# /kaggle/input/merged-dataset/test/normal/image_243.png
# /kaggle/input/merged-dataset/test/normal/image_245.png
# /kaggle/input/merged-dataset/test/normal/image_39.png
# /kaggle/input/merged-dataset/test/normal/image_12.png
# /kaggle/input/merged-dataset/test/normal/image_200.png
# /kaggle/input/merged-dataset/test/normal/image_55.png
# /kaggle/input/merged-dataset/test/normal/image_11.png
# /kaggle/input/merged-dataset/test/normal/image_89.png
# /kaggle/input/merged-dataset/test/normal/image_140.png
# /kaggle/input/merged-dataset/test/normal/image_205.png
# /kaggle/input/merged-dataset/test/normal/image_16.png
# /kaggle/input/merged-dataset/test/normal/image_212.png
# /kaggle/input/merged-dataset/test/normal/image_112.png
# /kaggle/input/merged-dataset/test/normal/image_225.png
# /kaggle/input/merged-dataset/test/normal/image_244.png
# /kaggle/input/merged-dataset/test/normal/image_56.png
# /kaggle/input/merged-dataset/test/normal/image_67.png
# /kaggle/input/merged-dataset/test/normal/image_228.png
# /kaggle/input/merged-dataset/test/normal/image_197.png
# /kaggle/input/merged-dataset/test/normal/image_233.png
# /kaggle/input/merged-dataset/test/normal/image_194.png
# /kaggle/input/merged-dataset/test/normal/image_23.png
# /kaggle/input/merged-dataset/test/normal/image_247.png
# /kaggle/input/merged-dataset/test/normal/image_66.png
# /kaggle/input/merged-dataset/test/normal/image_59.png
# /kaggle/input/merged-dataset/test/normal/image_169.png
# /kaggle/input/merged-dataset/test/normal/image_90.png
# /kaggle/input/merged-dataset/test/normal/image_142.png
# /kaggle/input/merged-dataset/test/normal/image_143.png
# /kaggle/input/merged-dataset/test/normal/image_196.png
# /kaggle/input/merged-dataset/test/normal/image_19.png
# /kaggle/input/merged-dataset/test/normal/image_29.png
# /kaggle/input/merged-dataset/test/normal/image_63.png
# /kaggle/input/merged-dataset/test/normal/image_64.png
# /kaggle/input/merged-dataset/test/normal/image_231.png
# /kaggle/input/merged-dataset/test/normal/image_86.png
# /kaggle/input/merged-dataset/test/normal/image_91.png
# /kaggle/input/merged-dataset/test/normal/image_70.png
# /kaggle/input/merged-dataset/test/normal/image_129.png
# /kaggle/input/merged-dataset/test/normal/image_104.png
# /kaggle/input/merged-dataset/test/normal/image_88.png
# /kaggle/input/merged-dataset/test/normal/image_71.png
# /kaggle/input/merged-dataset/test/normal/image_178.png
# /kaggle/input/merged-dataset/test/normal/image_163.png
# /kaggle/input/merged-dataset/test/normal/image_134.png
# /kaggle/input/merged-dataset/test/normal/image_173.png
# /kaggle/input/merged-dataset/test/normal/image_204.png
# /kaggle/input/merged-dataset/test/normal/image_110.png
# /kaggle/input/merged-dataset/test/normal/image_123.png
# /kaggle/input/merged-dataset/test/normal/image_246.png
# /kaggle/input/merged-dataset/test/normal/image_113.png
# /kaggle/input/merged-dataset/test/normal/image_162.png
# /kaggle/input/merged-dataset/test/normal/image_74.png
# /kaggle/input/merged-dataset/test/normal/image_216.png
# /kaggle/input/merged-dataset/test/normal/image_111.png
# /kaggle/input/merged-dataset/test/normal/image_136.png
# /kaggle/input/merged-dataset/test/normal/image_100.png
# /kaggle/input/merged-dataset/test/normal/image_209.png
# /kaggle/input/merged-dataset/test/normal/image_118.png
# /kaggle/input/merged-dataset/test/normal/image_107.png
# /kaggle/input/merged-dataset/test/normal/image_232.png
# /kaggle/input/merged-dataset/test/normal/image_94.png
# /kaggle/input/merged-dataset/test/normal/image_170.png
# /kaggle/input/merged-dataset/test/normal/image_26.png
# /kaggle/input/merged-dataset/test/normal/image_122.png
# /kaggle/input/merged-dataset/test/normal/image_202.png
# /kaggle/input/merged-dataset/test/normal/image_117.png
# /kaggle/input/merged-dataset/test/normal/image_190.png
# /kaggle/input/merged-dataset/test/normal/image_105.png
# /kaggle/input/merged-dataset/test/normal/image_17.png
# /kaggle/input/merged-dataset/test/normal/image_14.png
# /kaggle/input/merged-dataset/test/normal/image_80.png
# /kaggle/input/merged-dataset/test/normal/image_141.png
# /kaggle/input/merged-dataset/test/normal/image_148.png
# /kaggle/input/merged-dataset/test/normal/image_211.png
# /kaggle/input/merged-dataset/test/normal/image_207.png
# /kaggle/input/merged-dataset/test/normal/image_127.png
# /kaggle/input/merged-dataset/test/normal/image_72.png
# /kaggle/input/merged-dataset/test/normal/image_77.png
# /kaggle/input/merged-dataset/test/normal/image_73.png
# /kaggle/input/merged-dataset/test/normal/image_239.png
# /kaggle/input/merged-dataset/test/normal/image_27.png
# /kaggle/input/merged-dataset/test/normal/image_35.png
# /kaggle/input/merged-dataset/test/normal/image_4.png
# /kaggle/input/merged-dataset/test/normal/image_230.png
# /kaggle/input/merged-dataset/test/normal/image_36.png
# /kaggle/input/merged-dataset/test/normal/image_43.png
# /kaggle/input/merged-dataset/test/normal/image_60.png
# /kaggle/input/merged-dataset/test/normal/image_165.png
# /kaggle/input/merged-dataset/test/covid19/image_221.png
# /kaggle/input/merged-dataset/test/covid19/image_37.png
# /kaggle/input/merged-dataset/test/covid19/image_85.png
# /kaggle/input/merged-dataset/test/covid19/image_138.png
# /kaggle/input/merged-dataset/test/covid19/image_159.png
# /kaggle/input/merged-dataset/test/covid19/image_108.png
# /kaggle/input/merged-dataset/test/covid19/image_103.png
# /kaggle/input/merged-dataset/test/covid19/image_0.png
# /kaggle/input/merged-dataset/test/covid19/image_126.png
# /kaggle/input/merged-dataset/test/covid19/image_160.png
# /kaggle/input/merged-dataset/test/covid19/image_120.png
# /kaggle/input/merged-dataset/test/covid19/image_40.png
# /kaggle/input/merged-dataset/test/covid19/image_69.png
# /kaggle/input/merged-dataset/test/covid19/image_217.png
# /kaggle/input/merged-dataset/test/covid19/image_3.png
# /kaggle/input/merged-dataset/test/covid19/image_44.png
# /kaggle/input/merged-dataset/test/covid19/image_248.png
# /kaggle/input/merged-dataset/test/covid19/image_164.png
# /kaggle/input/merged-dataset/test/covid19/image_76.png
# /kaggle/input/merged-dataset/test/covid19/image_25.png
# /kaggle/input/merged-dataset/test/covid19/image_2.png
# /kaggle/input/merged-dataset/test/covid19/image_208.png
# /kaggle/input/merged-dataset/test/covid19/image_223.png
# /kaggle/input/merged-dataset/test/covid19/image_152.png
# /kaggle/input/merged-dataset/test/covid19/image_124.png
# /kaggle/input/merged-dataset/test/covid19/image_92.png
# /kaggle/input/merged-dataset/test/covid19/image_187.png
# /kaggle/input/merged-dataset/test/covid19/image_28.png
# /kaggle/input/merged-dataset/test/covid19/image_102.png
# /kaggle/input/merged-dataset/test/covid19/image_5.png
# /kaggle/input/merged-dataset/test/covid19/image_183.png
# /kaggle/input/merged-dataset/test/covid19/image_188.png
# /kaggle/input/merged-dataset/test/covid19/image_18.png
# /kaggle/input/merged-dataset/test/covid19/image_149.png
# /kaggle/input/merged-dataset/test/covid19/image_155.png
# /kaggle/input/merged-dataset/test/covid19/image_87.png
# /kaggle/input/merged-dataset/test/covid19/image_114.png
# /kaggle/input/merged-dataset/test/covid19/image_31.png
# /kaggle/input/merged-dataset/test/covid19/image_20.png
# /kaggle/input/merged-dataset/test/covid19/image_168.png
# /kaggle/input/merged-dataset/test/covid19/image_177.png
# /kaggle/input/merged-dataset/test/covid19/image_182.png
# /kaggle/input/merged-dataset/test/covid19/image_51.png
# /kaggle/input/merged-dataset/test/covid19/image_41.png
# /kaggle/input/merged-dataset/test/covid19/image_147.png
# /kaggle/input/merged-dataset/test/covid19/image_167.png
# /kaggle/input/merged-dataset/test/covid19/image_154.png
# /kaggle/input/merged-dataset/test/covid19/image_54.png
# /kaggle/input/merged-dataset/test/covid19/image_32.png
# /kaggle/input/merged-dataset/test/covid19/image_238.png
# /kaggle/input/merged-dataset/test/covid19/image_185.png
# /kaggle/input/merged-dataset/test/covid19/image_236.png
# /kaggle/input/merged-dataset/test/covid19/image_97.png
# /kaggle/input/merged-dataset/test/covid19/image_96.png
# /kaggle/input/merged-dataset/test/covid19/image_192.png
# /kaggle/input/merged-dataset/test/covid19/image_193.png
# /kaggle/input/merged-dataset/test/covid19/image_224.png
# /kaggle/input/merged-dataset/test/covid19/image_218.png
# /kaggle/input/merged-dataset/test/covid19/image_222.png
# /kaggle/input/merged-dataset/test/covid19/image_219.png
# /kaggle/input/merged-dataset/test/covid19/image_99.png
# /kaggle/input/merged-dataset/test/covid19/image_79.png
# /kaggle/input/merged-dataset/test/covid19/image_42.png
# /kaggle/input/merged-dataset/test/covid19/image_48.png
# /kaggle/input/merged-dataset/test/covid19/image_229.png
# /kaggle/input/merged-dataset/test/covid19/image_46.png
# /kaggle/input/merged-dataset/test/covid19/image_7.png
# /kaggle/input/merged-dataset/test/covid19/image_195.png
# /kaggle/input/merged-dataset/test/covid19/image_10.png
# /kaggle/input/merged-dataset/test/covid19/image_115.png
# /kaggle/input/merged-dataset/test/covid19/image_34.png
# /kaggle/input/merged-dataset/test/covid19/image_186.png
# /kaggle/input/merged-dataset/test/covid19/image_84.png
# /kaggle/input/merged-dataset/test/covid19/image_38.png
# /kaggle/input/merged-dataset/test/covid19/image_176.png
# /kaggle/input/merged-dataset/test/covid19/image_83.png
# /kaggle/input/merged-dataset/test/covid19/image_189.png
# /kaggle/input/merged-dataset/test/covid19/image_130.png
# /kaggle/input/merged-dataset/test/covid19/image_242.png
# /kaggle/input/merged-dataset/test/covid19/image_139.png
# /kaggle/input/merged-dataset/test/covid19/image_214.png
# /kaggle/input/merged-dataset/test/covid19/image_50.png
# /kaggle/input/merged-dataset/test/covid19/image_226.png
# /kaggle/input/merged-dataset/test/covid19/image_53.png
# /kaggle/input/merged-dataset/test/covid19/image_52.png
# /kaggle/input/merged-dataset/test/covid19/image_95.png
# /kaggle/input/merged-dataset/test/covid19/image_65.png
# /kaggle/input/merged-dataset/test/covid19/image_146.png
# /kaggle/input/merged-dataset/test/covid19/image_68.png
# /kaggle/input/merged-dataset/test/covid19/image_47.png
# /kaggle/input/merged-dataset/test/covid19/image_21.png
# /kaggle/input/merged-dataset/test/covid19/image_125.png
# /kaggle/input/merged-dataset/test/covid19/image_145.png
# /kaggle/input/merged-dataset/test/covid19/image_235.png
# /kaggle/input/merged-dataset/test/covid19/image_62.png
# /kaggle/input/merged-dataset/test/covid19/image_9.png
# /kaggle/input/merged-dataset/test/covid19/image_237.png
# /kaggle/input/merged-dataset/test/covid19/image_171.png
# /kaggle/input/merged-dataset/test/covid19/image_30.png
# /kaggle/input/merged-dataset/test/covid19/image_24.png
# /kaggle/input/merged-dataset/test/covid19/image_132.png
# /kaggle/input/merged-dataset/train/pneumonia/image_806.png
# /kaggle/input/merged-dataset/train/pneumonia/image_775.png
# /kaggle/input/merged-dataset/train/pneumonia/image_213.png
# /kaggle/input/merged-dataset/train/pneumonia/image_483.png
# /kaggle/input/merged-dataset/train/pneumonia/image_641.png
# /kaggle/input/merged-dataset/train/pneumonia/image_707.png
# /kaggle/input/merged-dataset/train/pneumonia/image_616.png
# /kaggle/input/merged-dataset/train/pneumonia/image_856.png
# /kaggle/input/merged-dataset/train/pneumonia/image_640.png
# /kaggle/input/merged-dataset/train/pneumonia/image_891.png
# /kaggle/input/merged-dataset/train/pneumonia/image_22.png
# /kaggle/input/merged-dataset/train/pneumonia/image_508.png
# /kaggle/input/merged-dataset/train/pneumonia/image_504.png
# /kaggle/input/merged-dataset/train/pneumonia/image_316.png
# /kaggle/input/merged-dataset/train/pneumonia/image_159.png
# /kaggle/input/merged-dataset/train/pneumonia/image_489.png
# /kaggle/input/merged-dataset/train/pneumonia/image_156.png
# /kaggle/input/merged-dataset/train/pneumonia/image_711.png
# /kaggle/input/merged-dataset/train/pneumonia/image_406.png
# /kaggle/input/merged-dataset/train/pneumonia/image_454.png
# /kaggle/input/merged-dataset/train/pneumonia/image_964.png
# /kaggle/input/merged-dataset/train/pneumonia/image_954.png
# /kaggle/input/merged-dataset/train/pneumonia/image_135.png
# /kaggle/input/merged-dataset/train/pneumonia/image_585.png
# /kaggle/input/merged-dataset/train/pneumonia/image_979.png
# /kaggle/input/merged-dataset/train/pneumonia/image_58.png
# /kaggle/input/merged-dataset/train/pneumonia/image_307.png
# /kaggle/input/merged-dataset/train/pneumonia/image_39.png
# /kaggle/input/merged-dataset/train/pneumonia/image_397.png
# /kaggle/input/merged-dataset/train/pneumonia/image_957.png
# /kaggle/input/merged-dataset/train/pneumonia/image_815.png
# /kaggle/input/merged-dataset/train/pneumonia/image_124.png
# /kaggle/input/merged-dataset/train/pneumonia/image_499.png
# /kaggle/input/merged-dataset/train/pneumonia/image_92.png
# /kaggle/input/merged-dataset/train/pneumonia/image_701.png
# /kaggle/input/merged-dataset/train/pneumonia/image_914.png
# /kaggle/input/merged-dataset/train/pneumonia/image_579.png
# /kaggle/input/merged-dataset/train/pneumonia/image_743.png
# /kaggle/input/merged-dataset/train/pneumonia/image_611.png
# /kaggle/input/merged-dataset/train/pneumonia/image_269.png
# /kaggle/input/merged-dataset/train/pneumonia/image_187.png
# /kaggle/input/merged-dataset/train/pneumonia/image_627.png
# /kaggle/input/merged-dataset/train/pneumonia/image_838.png
# /kaggle/input/merged-dataset/train/pneumonia/image_28.png
# /kaggle/input/merged-dataset/train/pneumonia/image_524.png
# /kaggle/input/merged-dataset/train/pneumonia/image_318.png
# /kaggle/input/merged-dataset/train/pneumonia/image_335.png
# /kaggle/input/merged-dataset/train/pneumonia/image_932.png
# /kaggle/input/merged-dataset/train/pneumonia/image_5.png
# /kaggle/input/merged-dataset/train/pneumonia/image_428.png
# /kaggle/input/merged-dataset/train/pneumonia/image_374.png
# /kaggle/input/merged-dataset/train/pneumonia/image_339.png
# /kaggle/input/merged-dataset/train/pneumonia/image_576.png
# /kaggle/input/merged-dataset/train/pneumonia/image_818.png
# /kaggle/input/merged-dataset/train/pneumonia/image_571.png
# /kaggle/input/merged-dataset/train/pneumonia/image_753.png
# /kaggle/input/merged-dataset/train/pneumonia/image_205.png
# /kaggle/input/merged-dataset/train/pneumonia/image_726.png
# /kaggle/input/merged-dataset/train/pneumonia/image_341.png
# /kaggle/input/merged-dataset/train/pneumonia/image_465.png
# /kaggle/input/merged-dataset/train/pneumonia/image_648.png
# /kaggle/input/merged-dataset/train/pneumonia/image_298.png
# /kaggle/input/merged-dataset/train/pneumonia/image_56.png
# /kaggle/input/merged-dataset/train/pneumonia/image_464.png
# /kaggle/input/merged-dataset/train/pneumonia/image_622.png
# /kaggle/input/merged-dataset/train/pneumonia/image_375.png
# /kaggle/input/merged-dataset/train/pneumonia/image_333.png
# /kaggle/input/merged-dataset/train/pneumonia/image_327.png
# /kaggle/input/merged-dataset/train/pneumonia/image_977.png
# /kaggle/input/merged-dataset/train/pneumonia/image_973.png
# /kaggle/input/merged-dataset/train/pneumonia/image_228.png
# /kaggle/input/merged-dataset/train/pneumonia/image_531.png
# /kaggle/input/merged-dataset/train/pneumonia/image_566.png
# /kaggle/input/merged-dataset/train/pneumonia/image_754.png
# /kaggle/input/merged-dataset/train/pneumonia/image_980.png
# /kaggle/input/merged-dataset/train/pneumonia/image_367.png
# /kaggle/input/merged-dataset/train/pneumonia/image_23.png
# /kaggle/input/merged-dataset/train/pneumonia/image_254.png
# /kaggle/input/merged-dataset/train/pneumonia/image_624.png
# /kaggle/input/merged-dataset/train/pneumonia/image_353.png
# /kaggle/input/merged-dataset/train/pneumonia/image_234.png
# /kaggle/input/merged-dataset/train/pneumonia/image_33.png
# /kaggle/input/merged-dataset/train/pneumonia/image_167.png
# /kaggle/input/merged-dataset/train/pneumonia/image_650.png
# /kaggle/input/merged-dataset/train/pneumonia/image_473.png
# /kaggle/input/merged-dataset/train/pneumonia/image_526.png
# /kaggle/input/merged-dataset/train/pneumonia/image_735.png
# /kaggle/input/merged-dataset/train/pneumonia/image_236.png
# /kaggle/input/merged-dataset/train/pneumonia/image_854.png
# /kaggle/input/merged-dataset/train/pneumonia/image_569.png
# /kaggle/input/merged-dataset/train/pneumonia/image_962.png
# /kaggle/input/merged-dataset/train/pneumonia/image_268.png
# /kaggle/input/merged-dataset/train/pneumonia/image_299.png
# /kaggle/input/merged-dataset/train/pneumonia/image_774.png
# /kaggle/input/merged-dataset/train/pneumonia/image_638.png
# /kaggle/input/merged-dataset/train/pneumonia/image_276.png
# /kaggle/input/merged-dataset/train/pneumonia/image_272.png
# /kaggle/input/merged-dataset/train/pneumonia/image_283.png
# /kaggle/input/merged-dataset/train/pneumonia/image_86.png
# /kaggle/input/merged-dataset/train/pneumonia/image_192.png
# /kaggle/input/merged-dataset/train/pneumonia/image_601.png
# /kaggle/input/merged-dataset/train/pneumonia/image_393.png
# /kaggle/input/merged-dataset/train/pneumonia/image_702.png
# /kaggle/input/merged-dataset/train/pneumonia/image_129.png
# /kaggle/input/merged-dataset/train/pneumonia/image_657.png
# /kaggle/input/merged-dataset/train/pneumonia/image_600.png
# /kaggle/input/merged-dataset/train/pneumonia/image_163.png
# /kaggle/input/merged-dataset/train/pneumonia/image_830.png
# /kaggle/input/merged-dataset/train/pneumonia/image_635.png
# /kaggle/input/merged-dataset/train/pneumonia/image_409.png
# /kaggle/input/merged-dataset/train/pneumonia/image_541.png
# /kaggle/input/merged-dataset/train/pneumonia/image_474.png
# /kaggle/input/merged-dataset/train/pneumonia/image_729.png
# /kaggle/input/merged-dataset/train/pneumonia/image_517.png
# /kaggle/input/merged-dataset/train/pneumonia/image_417.png
# /kaggle/input/merged-dataset/train/pneumonia/image_888.png
# /kaggle/input/merged-dataset/train/pneumonia/image_113.png
# /kaggle/input/merged-dataset/train/pneumonia/image_675.png
# /kaggle/input/merged-dataset/train/pneumonia/image_826.png
# /kaggle/input/merged-dataset/train/pneumonia/image_74.png
# /kaggle/input/merged-dataset/train/pneumonia/image_968.png
# /kaggle/input/merged-dataset/train/pneumonia/image_800.png
# /kaggle/input/merged-dataset/train/pneumonia/image_546.png
# /kaggle/input/merged-dataset/train/pneumonia/image_833.png
# /kaggle/input/merged-dataset/train/pneumonia/image_111.png
# /kaggle/input/merged-dataset/train/pneumonia/image_157.png
# /kaggle/input/merged-dataset/train/pneumonia/image_479.png
# /kaggle/input/merged-dataset/train/pneumonia/image_186.png
# /kaggle/input/merged-dataset/train/pneumonia/image_336.png
# /kaggle/input/merged-dataset/train/pneumonia/image_399.png
# /kaggle/input/merged-dataset/train/pneumonia/image_136.png
# /kaggle/input/merged-dataset/train/pneumonia/image_100.png
# /kaggle/input/merged-dataset/train/pneumonia/image_84.png
# /kaggle/input/merged-dataset/train/pneumonia/image_693.png
# /kaggle/input/merged-dataset/train/pneumonia/image_480.png
# /kaggle/input/merged-dataset/train/pneumonia/image_813.png
# /kaggle/input/merged-dataset/train/pneumonia/image_908.png
# /kaggle/input/merged-dataset/train/pneumonia/image_549.png
# /kaggle/input/merged-dataset/train/pneumonia/image_781.png
# /kaggle/input/merged-dataset/train/pneumonia/image_574.png
# /kaggle/input/merged-dataset/train/pneumonia/image_337.png
# /kaggle/input/merged-dataset/train/pneumonia/image_643.png
# /kaggle/input/merged-dataset/train/pneumonia/image_584.png
# /kaggle/input/merged-dataset/train/pneumonia/image_502.png
# /kaggle/input/merged-dataset/train/pneumonia/image_170.png
# /kaggle/input/merged-dataset/train/pneumonia/image_26.png
# /kaggle/input/merged-dataset/train/pneumonia/image_942.png
# /kaggle/input/merged-dataset/train/pneumonia/image_785.png
# /kaggle/input/merged-dataset/train/pneumonia/image_151.png
# /kaggle/input/merged-dataset/train/pneumonia/image_940.png
# /kaggle/input/merged-dataset/train/pneumonia/image_105.png
# /kaggle/input/merged-dataset/train/pneumonia/image_95.png
# /kaggle/input/merged-dataset/train/pneumonia/image_721.png
# /kaggle/input/merged-dataset/train/pneumonia/image_723.png
# /kaggle/input/merged-dataset/train/pneumonia/image_769.png
# /kaggle/input/merged-dataset/train/pneumonia/image_270.png
# /kaggle/input/merged-dataset/train/pneumonia/image_525.png
# /kaggle/input/merged-dataset/train/pneumonia/image_440.png
# /kaggle/input/merged-dataset/train/pneumonia/image_698.png
# /kaggle/input/merged-dataset/train/pneumonia/image_471.png
# /kaggle/input/merged-dataset/train/pneumonia/image_852.png
# /kaggle/input/merged-dataset/train/pneumonia/image_926.png
# /kaggle/input/merged-dataset/train/pneumonia/image_562.png
# /kaggle/input/merged-dataset/train/pneumonia/image_329.png
# /kaggle/input/merged-dataset/train/pneumonia/image_456.png
# /kaggle/input/merged-dataset/train/pneumonia/image_791.png
# /kaggle/input/merged-dataset/train/pneumonia/image_207.png
# /kaggle/input/merged-dataset/train/pneumonia/image_509.png
# /kaggle/input/merged-dataset/train/pneumonia/image_72.png
# /kaggle/input/merged-dataset/train/pneumonia/image_924.png
# /kaggle/input/merged-dataset/train/pneumonia/image_77.png
# /kaggle/input/merged-dataset/train/pneumonia/image_896.png
# /kaggle/input/merged-dataset/train/pneumonia/image_764.png
# /kaggle/input/merged-dataset/train/pneumonia/image_73.png
# /kaggle/input/merged-dataset/train/pneumonia/image_975.png
# /kaggle/input/merged-dataset/train/pneumonia/image_890.png
# /kaggle/input/merged-dataset/train/pneumonia/image_666.png
# /kaggle/input/merged-dataset/train/pneumonia/image_441.png
# /kaggle/input/merged-dataset/train/pneumonia/image_289.png
# /kaggle/input/merged-dataset/train/pneumonia/image_235.png
# /kaggle/input/merged-dataset/train/pneumonia/image_559.png
# /kaggle/input/merged-dataset/train/pneumonia/image_444.png
# /kaggle/input/merged-dataset/train/pneumonia/image_669.png
# /kaggle/input/merged-dataset/train/pneumonia/image_934.png
# /kaggle/input/merged-dataset/train/pneumonia/image_306.png
# /kaggle/input/merged-dataset/train/pneumonia/image_623.png
# /kaggle/input/merged-dataset/train/pneumonia/image_591.png
# /kaggle/input/merged-dataset/train/pneumonia/image_291.png
# /kaggle/input/merged-dataset/train/pneumonia/image_797.png
# /kaggle/input/merged-dataset/train/pneumonia/image_857.png
# /kaggle/input/merged-dataset/train/pneumonia/image_907.png
# /kaggle/input/merged-dataset/train/pneumonia/image_596.png
# /kaggle/input/merged-dataset/train/pneumonia/image_383.png
# /kaggle/input/merged-dataset/train/pneumonia/image_385.png
# /kaggle/input/merged-dataset/train/normal/image_281.png
# /kaggle/input/merged-dataset/train/normal/image_418.png
# /kaggle/input/merged-dataset/train/normal/image_350.png
# /kaggle/input/merged-dataset/train/normal/image_334.png
# /kaggle/input/merged-dataset/train/normal/image_761.png
# /kaggle/input/merged-dataset/train/normal/image_372.png
# /kaggle/input/merged-dataset/train/normal/image_779.png
# /kaggle/input/merged-dataset/train/normal/image_515.png
# /kaggle/input/merged-dataset/train/normal/image_487.png
# /kaggle/input/merged-dataset/train/normal/image_6.png
# /kaggle/input/merged-dataset/train/normal/image_37.png
# /kaggle/input/merged-dataset/train/normal/image_253.png
# /kaggle/input/merged-dataset/train/normal/image_819.png
# /kaggle/input/merged-dataset/train/normal/image_955.png
# /kaggle/input/merged-dataset/train/normal/image_426.png
# /kaggle/input/merged-dataset/train/normal/image_150.png
# /kaggle/input/merged-dataset/train/normal/image_180.png
# /kaggle/input/merged-dataset/train/normal/image_138.png
# /kaggle/input/merged-dataset/train/normal/image_93.png
# /kaggle/input/merged-dataset/train/normal/image_198.png
# /kaggle/input/merged-dataset/train/normal/image_265.png
# /kaggle/input/merged-dataset/train/normal/image_435.png
# /kaggle/input/merged-dataset/train/normal/image_411.png
# /kaggle/input/merged-dataset/train/normal/image_137.png
# /kaggle/input/merged-dataset/train/normal/image_787.png
# /kaggle/input/merged-dataset/train/normal/image_103.png
# /kaggle/input/merged-dataset/train/normal/image_990.png
# /kaggle/input/merged-dataset/train/normal/image_0.png
# /kaggle/input/merged-dataset/train/normal/image_120.png
# /kaggle/input/merged-dataset/train/normal/image_503.png
# /kaggle/input/merged-dataset/train/normal/image_836.png
# /kaggle/input/merged-dataset/train/normal/image_311.png
# /kaggle/input/merged-dataset/train/normal/image_40.png
# /kaggle/input/merged-dataset/train/normal/image_824.png
# /kaggle/input/merged-dataset/train/normal/image_644.png
# /kaggle/input/merged-dataset/train/normal/image_390.png
# /kaggle/input/merged-dataset/train/normal/image_452.png
# /kaggle/input/merged-dataset/train/normal/image_217.png
# /kaggle/input/merged-dataset/train/normal/image_432.png
# /kaggle/input/merged-dataset/train/normal/image_485.png
# /kaggle/input/merged-dataset/train/normal/image_459.png
# /kaggle/input/merged-dataset/train/normal/image_829.png
# /kaggle/input/merged-dataset/train/normal/image_319.png
# /kaggle/input/merged-dataset/train/normal/image_552.png
# /kaggle/input/merged-dataset/train/normal/image_379.png
# /kaggle/input/merged-dataset/train/normal/image_748.png
# /kaggle/input/merged-dataset/train/normal/image_578.png
# /kaggle/input/merged-dataset/train/normal/image_363.png
# /kaggle/input/merged-dataset/train/normal/image_448.png
# /kaggle/input/merged-dataset/train/normal/image_286.png
# /kaggle/input/merged-dataset/train/normal/image_44.png
# /kaggle/input/merged-dataset/train/normal/image_248.png
# /kaggle/input/merged-dataset/train/normal/image_953.png
# /kaggle/input/merged-dataset/train/normal/image_287.png
# /kaggle/input/merged-dataset/train/normal/image_343.png
# /kaggle/input/merged-dataset/train/normal/image_389.png
# /kaggle/input/merged-dataset/train/normal/image_460.png
# /kaggle/input/merged-dataset/train/normal/image_738.png
# /kaggle/input/merged-dataset/train/normal/image_548.png
# /kaggle/input/merged-dataset/train/normal/image_245.png
# /kaggle/input/merged-dataset/train/normal/image_416.png
# /kaggle/input/merged-dataset/train/normal/image_166.png
# /kaggle/input/merged-dataset/train/normal/image_25.png
# /kaggle/input/merged-dataset/train/normal/image_614.png
# /kaggle/input/merged-dataset/train/normal/image_544.png
# /kaggle/input/merged-dataset/train/normal/image_208.png
# /kaggle/input/merged-dataset/train/normal/image_422.png
# /kaggle/input/merged-dataset/train/normal/image_312.png
# /kaggle/input/merged-dataset/train/normal/image_841.png
# /kaggle/input/merged-dataset/train/normal/image_981.png
# /kaggle/input/merged-dataset/train/normal/image_377.png
# /kaggle/input/merged-dataset/train/normal/image_437.png
# /kaggle/input/merged-dataset/train/normal/image_758.png
# /kaggle/input/merged-dataset/train/normal/image_201.png
# /kaggle/input/merged-dataset/train/normal/image_55.png
# /kaggle/input/merged-dataset/train/normal/image_438.png
# /kaggle/input/merged-dataset/train/normal/image_732.png
# /kaggle/input/merged-dataset/train/normal/image_529.png
# /kaggle/input/merged-dataset/train/normal/image_916.png
# /kaggle/input/merged-dataset/train/normal/image_906.png
# /kaggle/input/merged-dataset/train/normal/image_518.png
# /kaggle/input/merged-dataset/train/normal/image_661.png
# /kaggle/input/merged-dataset/train/normal/image_901.png
# /kaggle/input/merged-dataset/train/normal/image_943.png
# /kaggle/input/merged-dataset/train/normal/image_557.png
# /kaggle/input/merged-dataset/train/normal/image_740.png
# /kaggle/input/merged-dataset/train/normal/image_102.png
# /kaggle/input/merged-dataset/train/normal/image_599.png
# /kaggle/input/merged-dataset/train/normal/image_674.png
# /kaggle/input/merged-dataset/train/normal/image_153.png
# /kaggle/input/merged-dataset/train/normal/image_683.png
# /kaggle/input/merged-dataset/train/normal/image_715.png
# /kaggle/input/merged-dataset/train/normal/image_382.png
# /kaggle/input/merged-dataset/train/normal/image_864.png
# /kaggle/input/merged-dataset/train/normal/image_267.png
# /kaggle/input/merged-dataset/train/normal/image_188.png
# /kaggle/input/merged-dataset/train/normal/image_407.png
# /kaggle/input/merged-dataset/train/normal/image_751.png
# /kaggle/input/merged-dataset/train/normal/image_184.png
# /kaggle/input/merged-dataset/train/normal/image_554.png
# /kaggle/input/merged-dataset/train/normal/image_604.png
# /kaggle/input/merged-dataset/train/normal/image_514.png
# /kaggle/input/merged-dataset/train/normal/image_332.png
# /kaggle/input/merged-dataset/train/normal/image_874.png
# /kaggle/input/merged-dataset/train/normal/image_387.png
# /kaggle/input/merged-dataset/train/normal/image_689.png
# /kaggle/input/merged-dataset/train/normal/image_862.png
# /kaggle/input/merged-dataset/train/normal/image_776.png
# /kaggle/input/merged-dataset/train/normal/image_985.png
# /kaggle/input/merged-dataset/train/normal/image_18.png
# /kaggle/input/merged-dataset/train/normal/image_280.png
# /kaggle/input/merged-dataset/train/normal/image_149.png
# /kaggle/input/merged-dataset/train/normal/image_770.png
# /kaggle/input/merged-dataset/train/normal/image_905.png
# /kaggle/input/merged-dataset/train/normal/image_305.png
# /kaggle/input/merged-dataset/train/normal/image_560.png
# /kaggle/input/merged-dataset/train/normal/image_619.png
# /kaggle/input/merged-dataset/train/normal/image_677.png
# /kaggle/input/merged-dataset/train/normal/image_633.png
# /kaggle/input/merged-dataset/train/normal/image_530.png
# /kaggle/input/merged-dataset/train/normal/image_381.png
# /kaggle/input/merged-dataset/train/normal/image_380.png
# /kaggle/input/merged-dataset/train/normal/image_469.png
# /kaggle/input/merged-dataset/train/normal/image_446.png
# /kaggle/input/merged-dataset/train/normal/image_285.png
# /kaggle/input/merged-dataset/train/normal/image_880.png
# /kaggle/input/merged-dataset/train/normal/image_114.png
# /kaggle/input/merged-dataset/train/normal/image_790.png
# /kaggle/input/merged-dataset/train/normal/image_369.png
# /kaggle/input/merged-dataset/train/normal/image_536.png
# /kaggle/input/merged-dataset/train/normal/image_492.png
# /kaggle/input/merged-dataset/train/normal/image_45.png
# /kaggle/input/merged-dataset/train/normal/image_31.png
# /kaggle/input/merged-dataset/train/normal/image_225.png
# /kaggle/input/merged-dataset/train/normal/image_649.png
# /kaggle/input/merged-dataset/train/normal/image_244.png
# /kaggle/input/merged-dataset/train/normal/image_831.png
# /kaggle/input/merged-dataset/train/normal/image_294.png
# /kaggle/input/merged-dataset/train/normal/image_894.png
# /kaggle/input/merged-dataset/train/normal/image_398.png
# /kaggle/input/merged-dataset/train/normal/image_946.png
# /kaggle/input/merged-dataset/train/normal/image_537.png
# /kaggle/input/merged-dataset/train/normal/image_168.png
# /kaggle/input/merged-dataset/train/normal/image_15.png
# /kaggle/input/merged-dataset/train/normal/image_782.png
# /kaggle/input/merged-dataset/train/normal/image_788.png
# /kaggle/input/merged-dataset/train/normal/image_697.png
# /kaggle/input/merged-dataset/train/normal/image_325.png
# /kaggle/input/merged-dataset/train/normal/image_172.png
# /kaggle/input/merged-dataset/train/normal/image_778.png
# /kaggle/input/merged-dataset/train/normal/image_909.png
# /kaggle/input/merged-dataset/train/normal/image_682.png
# /kaggle/input/merged-dataset/train/normal/image_144.png
# /kaggle/input/merged-dataset/train/normal/image_197.png
# /kaggle/input/merged-dataset/train/normal/image_402.png
# /kaggle/input/merged-dataset/train/normal/image_520.png
# /kaggle/input/merged-dataset/train/normal/image_921.png
# /kaggle/input/merged-dataset/train/normal/image_920.png
# /kaggle/input/merged-dataset/train/normal/image_182.png
# /kaggle/input/merged-dataset/train/normal/image_993.png
# /kaggle/input/merged-dataset/train/normal/image_543.png
# /kaggle/input/merged-dataset/train/normal/image_472.png
# /kaggle/input/merged-dataset/train/normal/image_565.png
# /kaggle/input/merged-dataset/train/normal/image_194.png
# /kaggle/input/merged-dataset/train/normal/image_858.png
# /kaggle/input/merged-dataset/train/normal/image_885.png
# /kaggle/input/merged-dataset/train/normal/image_121.png
# /kaggle/input/merged-dataset/train/normal/image_796.png
# /kaggle/input/merged-dataset/train/normal/image_989.png
# /kaggle/input/merged-dataset/train/normal/image_51.png
# /kaggle/input/merged-dataset/train/normal/image_825.png
# /kaggle/input/merged-dataset/train/normal/image_41.png
# /kaggle/input/merged-dataset/train/normal/image_822.png
# /kaggle/input/merged-dataset/train/normal/image_505.png
# /kaggle/input/merged-dataset/train/normal/image_902.png
# /kaggle/input/merged-dataset/train/normal/image_324.png
# /kaggle/input/merged-dataset/train/normal/image_952.png
# /kaggle/input/merged-dataset/train/normal/image_66.png
# /kaggle/input/merged-dataset/train/normal/image_154.png
# /kaggle/input/merged-dataset/train/normal/image_59.png
# /kaggle/input/merged-dataset/train/normal/image_696.png
# /kaggle/input/merged-dataset/train/normal/image_972.png
# /kaggle/input/merged-dataset/train/normal/image_673.png
# /kaggle/input/merged-dataset/train/normal/image_742.png
# /kaggle/input/merged-dataset/train/normal/image_54.png
# /kaggle/input/merged-dataset/train/normal/image_32.png
# /kaggle/input/merged-dataset/train/normal/image_238.png
# /kaggle/input/merged-dataset/train/normal/image_330.png
# /kaggle/input/merged-dataset/train/normal/image_427.png
# /kaggle/input/merged-dataset/train/normal/image_470.png
# /kaggle/input/merged-dataset/train/normal/image_884.png
# /kaggle/input/merged-dataset/train/normal/image_486.png
# /kaggle/input/merged-dataset/train/normal/image_143.png
# /kaggle/input/merged-dataset/train/normal/image_258.png
# /kaggle/input/merged-dataset/train/normal/image_528.png
# /kaggle/input/merged-dataset/train/normal/image_913.png
# /kaggle/input/merged-dataset/train/normal/image_688.png
# /kaggle/input/merged-dataset/train/normal/image_944.png
# /kaggle/input/merged-dataset/train/normal/image_695.png
# /kaggle/input/merged-dataset/train/normal/image_588.png
# /kaggle/input/merged-dataset/train/normal/image_196.png
# /kaggle/input/merged-dataset/train/normal/image_734.png
# /kaggle/input/merged-dataset/train/normal/image_835.png
# /kaggle/input/merged-dataset/train/normal/image_96.png
# /kaggle/input/merged-dataset/train/normal/image_949.png
# /kaggle/input/merged-dataset/train/normal/image_63.png
# /kaggle/input/merged-dataset/train/normal/image_64.png
# /kaggle/input/merged-dataset/train/normal/image_231.png
# /kaggle/input/merged-dataset/train/normal/image_297.png
# /kaggle/input/merged-dataset/train/normal/image_439.png
# /kaggle/input/merged-dataset/train/normal/image_969.png
# /kaggle/input/merged-dataset/train/normal/image_676.png
# /kaggle/input/merged-dataset/train/normal/image_842.png
# /kaggle/input/merged-dataset/train/normal/image_765.png
# /kaggle/input/merged-dataset/train/normal/image_193.png
# /kaggle/input/merged-dataset/train/normal/image_535.png
# /kaggle/input/merged-dataset/train/normal/image_224.png
# /kaggle/input/merged-dataset/train/normal/image_867.png
# /kaggle/input/merged-dataset/train/normal/image_91.png
# /kaggle/input/merged-dataset/train/normal/image_218.png
# /kaggle/input/merged-dataset/train/normal/image_219.png
# /kaggle/input/merged-dataset/train/normal/image_88.png
# /kaggle/input/merged-dataset/train/normal/image_550.png
# /kaggle/input/merged-dataset/train/normal/image_575.png
# /kaggle/input/merged-dataset/train/normal/image_71.png
# /kaggle/input/merged-dataset/train/normal/image_99.png
# /kaggle/input/merged-dataset/train/normal/image_927.png
# /kaggle/input/merged-dataset/train/normal/image_259.png
# /kaggle/input/merged-dataset/train/normal/image_173.png
# /kaggle/input/merged-dataset/train/normal/image_647.png
# /kaggle/input/merged-dataset/train/normal/image_873.png
# /kaggle/input/merged-dataset/train/normal/image_455.png
# /kaggle/input/merged-dataset/train/normal/image_861.png
# /kaggle/input/merged-dataset/train/normal/image_204.png
# /kaggle/input/merged-dataset/train/normal/image_249.png
# /kaggle/input/merged-dataset/train/normal/image_79.png
# /kaggle/input/merged-dataset/train/normal/image_362.png
# /kaggle/input/merged-dataset/train/normal/image_911.png
# /kaggle/input/merged-dataset/train/normal/image_42.png
# /kaggle/input/merged-dataset/train/normal/image_597.png
# /kaggle/input/merged-dataset/train/normal/image_625.png
# /kaggle/input/merged-dataset/train/normal/image_733.png
# /kaggle/input/merged-dataset/train/normal/image_636.png
# /kaggle/input/merged-dataset/train/normal/image_717.png
# /kaggle/input/merged-dataset/train/normal/image_533.png
# /kaggle/input/merged-dataset/train/normal/image_527.png
# /kaggle/input/merged-dataset/train/normal/image_431.png
# /kaggle/input/merged-dataset/train/normal/image_933.png
# /kaggle/input/merged-dataset/train/normal/image_467.png
# /kaggle/input/merged-dataset/train/normal/image_882.png
# /kaggle/input/merged-dataset/train/normal/image_655.png
# /kaggle/input/merged-dataset/train/normal/image_823.png
# /kaggle/input/merged-dataset/train/normal/image_716.png
# /kaggle/input/merged-dataset/train/normal/image_613.png
# /kaggle/input/merged-dataset/train/normal/image_731.png
# /kaggle/input/merged-dataset/train/normal/image_710.png
# /kaggle/input/merged-dataset/train/normal/image_637.png
# /kaggle/input/merged-dataset/train/normal/image_220.png
# /kaggle/input/merged-dataset/train/normal/image_48.png
# /kaggle/input/merged-dataset/train/normal/image_229.png
# /kaggle/input/merged-dataset/train/normal/image_46.png
# /kaggle/input/merged-dataset/train/normal/image_162.png
# /kaggle/input/merged-dataset/train/normal/image_321.png
# /kaggle/input/merged-dataset/train/normal/image_206.png
# /kaggle/input/merged-dataset/train/normal/image_720.png
# /kaggle/input/merged-dataset/train/normal/image_7.png
# /kaggle/input/merged-dataset/train/normal/image_414.png
# /kaggle/input/merged-dataset/train/normal/image_617.png
# /kaggle/input/merged-dataset/train/normal/image_629.png
# /kaggle/input/merged-dataset/train/normal/image_704.png
# /kaggle/input/merged-dataset/train/normal/image_10.png
# /kaggle/input/merged-dataset/train/normal/image_241.png
# /kaggle/input/merged-dataset/train/normal/image_109.png
# /kaggle/input/merged-dataset/train/normal/image_466.png
# /kaggle/input/merged-dataset/train/normal/image_877.png
# /kaggle/input/merged-dataset/train/normal/image_355.png
# /kaggle/input/merged-dataset/train/normal/image_925.png
# /kaggle/input/merged-dataset/train/normal/image_846.png
# /kaggle/input/merged-dataset/train/normal/image_447.png
# /kaggle/input/merged-dataset/train/normal/image_878.png
# /kaggle/input/merged-dataset/train/normal/image_727.png
# /kaggle/input/merged-dataset/train/normal/image_737.png
# /kaggle/input/merged-dataset/train/normal/image_451.png
# /kaggle/input/merged-dataset/train/normal/image_415.png
# /kaggle/input/merged-dataset/train/normal/image_481.png
# /kaggle/input/merged-dataset/train/normal/image_828.png
# /kaggle/input/merged-dataset/train/normal/image_118.png
# /kaggle/input/merged-dataset/train/normal/image_189.png
# /kaggle/input/merged-dataset/train/normal/image_904.png
# /kaggle/input/merged-dataset/train/normal/image_784.png
# /kaggle/input/merged-dataset/train/normal/image_563.png
# /kaggle/input/merged-dataset/train/normal/image_498.png
# /kaggle/input/merged-dataset/train/normal/image_539.png
# /kaggle/input/merged-dataset/train/normal/image_752.png
# /kaggle/input/merged-dataset/train/normal/image_654.png
# /kaggle/input/merged-dataset/train/normal/image_303.png
# /kaggle/input/merged-dataset/train/normal/image_618.png
# /kaggle/input/merged-dataset/train/normal/image_663.png
# /kaggle/input/merged-dataset/train/normal/image_686.png
# /kaggle/input/merged-dataset/train/normal/image_798.png
# /kaggle/input/merged-dataset/train/normal/image_532.png
# /kaggle/input/merged-dataset/train/normal/image_889.png
# /kaggle/input/merged-dataset/train/normal/image_255.png
# /kaggle/input/merged-dataset/train/normal/image_338.png
# /kaggle/input/merged-dataset/train/normal/image_678.png
# /kaggle/input/merged-dataset/train/normal/image_94.png
# /kaggle/input/merged-dataset/train/normal/image_358.png
# /kaggle/input/merged-dataset/train/normal/image_378.png
# /kaggle/input/merged-dataset/train/normal/image_122.png
# /kaggle/input/merged-dataset/train/normal/image_493.png
# /kaggle/input/merged-dataset/train/normal/image_202.png
# /kaggle/input/merged-dataset/train/normal/image_709.png
# /kaggle/input/merged-dataset/train/normal/image_843.png
# /kaggle/input/merged-dataset/train/normal/image_226.png
# /kaggle/input/merged-dataset/train/normal/image_930.png
# /kaggle/input/merged-dataset/train/normal/image_53.png
# /kaggle/input/merged-dataset/train/normal/image_190.png
# /kaggle/input/merged-dataset/train/normal/image_359.png
# /kaggle/input/merged-dataset/train/normal/image_300.png
# /kaggle/input/merged-dataset/train/normal/image_811.png
# /kaggle/input/merged-dataset/train/normal/image_510.png
# /kaggle/input/merged-dataset/train/normal/image_314.png
# /kaggle/input/merged-dataset/train/normal/image_577.png
# /kaggle/input/merged-dataset/train/normal/image_17.png
# /kaggle/input/merged-dataset/train/normal/image_639.png
# /kaggle/input/merged-dataset/train/normal/image_128.png
# /kaggle/input/merged-dataset/train/normal/image_555.png
# /kaggle/input/merged-dataset/train/normal/image_80.png
# /kaggle/input/merged-dataset/train/normal/image_396.png
# /kaggle/input/merged-dataset/train/normal/image_522.png
# /kaggle/input/merged-dataset/train/normal/image_8.png
# /kaggle/input/merged-dataset/train/normal/image_694.png
# /kaggle/input/merged-dataset/train/normal/image_146.png
# /kaggle/input/merged-dataset/train/normal/image_68.png
# /kaggle/input/merged-dataset/train/normal/image_931.png
# /kaggle/input/merged-dataset/train/normal/image_898.png
# /kaggle/input/merged-dataset/train/normal/image_608.png
# /kaggle/input/merged-dataset/train/normal/image_366.png
# /kaggle/input/merged-dataset/train/normal/image_807.png
# /kaggle/input/merged-dataset/train/normal/image_501.png
# /kaggle/input/merged-dataset/train/normal/image_970.png
# /kaggle/input/merged-dataset/train/normal/image_215.png
# /kaggle/input/merged-dataset/train/normal/image_342.png
# /kaggle/input/merged-dataset/train/normal/image_690.png
# /kaggle/input/merged-dataset/train/normal/image_21.png
# /kaggle/input/merged-dataset/train/normal/image_590.png
# /kaggle/input/merged-dataset/train/normal/image_978.png
# /kaggle/input/merged-dataset/train/normal/image_799.png
# /kaggle/input/merged-dataset/train/normal/image_872.png
# /kaggle/input/merged-dataset/train/normal/image_476.png
# /kaggle/input/merged-dataset/train/normal/image_125.png
# /kaggle/input/merged-dataset/train/normal/image_792.png
# /kaggle/input/merged-dataset/train/normal/image_368.png
# /kaggle/input/merged-dataset/train/normal/image_572.png
# /kaggle/input/merged-dataset/train/normal/image_412.png
# /kaggle/input/merged-dataset/train/normal/image_760.png
# /kaggle/input/merged-dataset/train/normal/image_240.png
# /kaggle/input/merged-dataset/train/normal/image_610.png
# /kaggle/input/merged-dataset/train/normal/image_551.png
# /kaggle/input/merged-dataset/train/normal/image_773.png
# /kaggle/input/merged-dataset/train/normal/image_75.png
# /kaggle/input/merged-dataset/train/normal/image_963.png
# /kaggle/input/merged-dataset/train/normal/image_252.png
# /kaggle/input/merged-dataset/train/normal/image_482.png
# /kaggle/input/merged-dataset/train/normal/image_631.png
# /kaggle/input/merged-dataset/train/normal/image_484.png
# /kaggle/input/merged-dataset/train/normal/image_594.png
# /kaggle/input/merged-dataset/train/normal/image_27.png
# /kaggle/input/merged-dataset/train/normal/image_687.png
# /kaggle/input/merged-dataset/train/normal/image_718.png
# /kaggle/input/merged-dataset/train/normal/image_290.png
# /kaggle/input/merged-dataset/train/normal/image_941.png
# /kaggle/input/merged-dataset/train/normal/image_971.png
# /kaggle/input/merged-dataset/train/normal/image_756.png
# /kaggle/input/merged-dataset/train/normal/image_421.png
# /kaggle/input/merged-dataset/train/normal/image_250.png
# /kaggle/input/merged-dataset/train/normal/image_500.png
# /kaggle/input/merged-dataset/train/normal/image_36.png
# /kaggle/input/merged-dataset/train/normal/image_580.png
# /kaggle/input/merged-dataset/train/normal/image_491.png
# /kaggle/input/merged-dataset/train/normal/image_581.png
# /kaggle/input/merged-dataset/train/normal/image_340.png
# /kaggle/input/merged-dataset/train/normal/image_453.png
# /kaggle/input/merged-dataset/train/normal/image_98.png
# /kaggle/input/merged-dataset/train/normal/image_804.png
# /kaggle/input/merged-dataset/train/normal/image_670.png
# /kaggle/input/merged-dataset/train/normal/image_257.png
# /kaggle/input/merged-dataset/train/normal/image_171.png
# /kaggle/input/merged-dataset/train/normal/image_814.png
# /kaggle/input/merged-dataset/train/normal/image_745.png
# /kaggle/input/merged-dataset/train/normal/image_808.png
# /kaggle/input/merged-dataset/train/normal/image_413.png
# /kaggle/input/merged-dataset/train/normal/image_279.png
# /kaggle/input/merged-dataset/train/normal/image_408.png
# /kaggle/input/merged-dataset/train/normal/image_371.png
# /kaggle/input/merged-dataset/train/normal/image_365.png
# /kaggle/input/merged-dataset/train/normal/image_165.png
# /kaggle/input/merged-dataset/train/normal/image_817.png
# /kaggle/input/merged-dataset/train/covid19/image_1.png
# /kaggle/input/merged-dataset/train/covid19/image_328.png
# /kaggle/input/merged-dataset/train/covid19/image_256.png
# /kaggle/input/merged-dataset/train/covid19/image_301.png
# /kaggle/input/merged-dataset/train/covid19/image_506.png
# /kaggle/input/merged-dataset/train/covid19/image_512.png
# /kaggle/input/merged-dataset/train/covid19/image_221.png
# /kaggle/input/merged-dataset/train/covid19/image_595.png
# ...
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(121).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(453).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(100).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(201).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(445).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(243).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(92).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(424).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(248).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(287).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(419).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(328).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(185).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(77).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(220).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(181).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(78).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(295).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(313).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(177).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(4).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(156).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(276).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(438).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(178).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(45).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(193).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(6).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(159).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(396).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(166).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(401).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(218).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(104).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(48).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(257).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(86).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(50).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(161).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(168).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(126).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(271).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(345).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(330).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(129).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(379).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(13).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(363).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(167).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(355).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(353).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(162).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(337).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(391).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(261).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(192).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(58).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(30).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(173).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(300).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(268).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(338).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(56).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(247).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(272).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(250).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(18).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(190).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(9).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(231).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(102).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(42).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(310).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(365).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(21).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(137).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(258).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(80).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(454).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(290).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(374).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(94).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(67).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(423).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(47).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(61).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(154).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(294).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(7).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(315).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(25).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(59).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(232).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(55).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(456).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(149).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(170).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(155).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(323).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(20).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(311).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(116).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(8).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(265).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(124).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(439).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(435).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(412).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(404).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(356).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(428).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(117).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(414).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(194).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(145).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(152).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(263).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(81).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(302).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(41).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(444).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(225).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(35).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(430).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(307).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(270).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(28).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(2).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(187).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(95).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(133).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(64).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(53).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(211).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(285).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(97).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(196).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(229).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(125).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(171).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(437).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(222).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(205).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(312).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(22).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(147).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(325).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(400).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(127).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(417).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(393).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(54).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(252).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(405).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(169).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(128).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(442).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(331).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(254).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(361).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(99).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(269).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(407).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(322).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(292).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(24).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(88).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(360).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(144).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(425).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(317).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(210).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(394).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(130).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(150).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(230).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(132).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(52).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(352).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(326).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(402).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(376).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(87).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(284).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(82).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(118).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(416).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(140).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(364).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(386).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(408).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(358).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(184).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(203).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(73).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(451).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(32).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(340).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(235).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(83).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(418).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(131).jpg
# /kaggle/input/chest-xray-covid19-pneumonia/Data/train/COVID19/COVID19(384).jpg

# %%
import os
import pandas as pd
from PIL import Image
import numpy as np
import cv2
import seaborn as sns
from tensorflow.keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
from PIL import Image
import shutil
from sklearn.model_selection import train_test_split
# Out:
# 2025-04-17 20:20:46.110247: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744921246.327980      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744921246.392023      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
base_path = '/kaggle/input/merged-dataset'

categories = ['covid19', 'normal', 'pneumonia']
images = []
labels = []

# %%
# Function to load images from a directory
def load_images_from_folder(folder, label):
    for filename in os.listdir(folder):
        if filename.endswith('.jpg') or filename.endswith('.png') :  # Only process .jpg files
            img_path = os.path.join(folder, filename)
            try:
                img = cv2.imread(img_path)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, (224, 224))
                images.append(img)
                labels.append(label)
            except Exception as e:
                print(f"Error loading image {img_path}: {e}")

# %%
train_path = os.path.join(base_path, 'train')
for category in categories:
    category_path = os.path.join(train_path, category)
    print(f"Loading training data from {category_path}...")
    load_images_from_folder(category_path, category)
    
test_path = os.path.join(base_path, 'test')
test_images = []
test_labels = []
for category in categories:
    category_path = os.path.join(test_path, category)
    print(f"Loading test data from {category_path}...")
    load_images_from_folder(category_path, category)
# Out:
# Loading training data from /kaggle/input/merged-dataset/train/covid19...
# Loading training data from /kaggle/input/merged-dataset/train/normal...
# Loading training data from /kaggle/input/merged-dataset/train/pneumonia...
# Loading test data from /kaggle/input/merged-dataset/test/covid19...
# Loading test data from /kaggle/input/merged-dataset/test/normal...
# Loading test data from /kaggle/input/merged-dataset/test/pneumonia...

# %%
images = np.array(images)
labels = np.array(labels)

# %% [markdown]
# # Dataset Summary

# %%
print("Number of images in total is ", len(images))
COVID19_count = 0
NORMAL_count = 0
PNEUMONIA_count = 0
for label in labels:
    if label == 'covid19':
        COVID19_count+=1
    elif label == 'normal':
        NORMAL_count +=1
    elif label == 'pneumonia':
        PNEUMONIA_count+=1
print(f"Number of images in COVID19 class is {COVID19_count}")
print(f"Number of images in NORMAL class is {NORMAL_count}")
print(f"Number of images in PNEUMONIA class is {PNEUMONIA_count}")
# Out:
# Number of images in total is  1244
# Number of images in COVID19 class is 504
# Number of images in NORMAL class is 498
# Number of images in PNEUMONIA class is 242

# %%
class_labels = ['COVID-19', 'Normal', 'Pneumonia']
counts = [COVID19_count, NORMAL_count, PNEUMONIA_count]

sns.set_style("whitegrid")
plt.figure(figsize=(8, 6))
sns.barplot(x=class_labels, y=counts, color='pink')

plt.title('Class Distribution of Chest X-ray Images', fontsize=14)
plt.xlabel('Class')
plt.ylabel('Number of Images')

plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
train_image_paths = []

for category in categories:
    category_path = os.path.join(train_path, category)
    for filename in os.listdir(category_path):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            full_path = os.path.join(category_path, filename)
            train_image_paths.append(full_path)

# %%
def check_image_modes(image_paths):
    mode_counts = {}
    for path in image_paths:
        try:
            with Image.open(path) as img:
                mode = img.mode  # 'L' for grayscale, 'RGB' for color
                mode_counts[mode] = mode_counts.get(mode, 0) + 1
        except Exception as e:
            print(f"Error opening {path}: {e}")
    return mode_counts

# %%
mode_summary = check_image_modes(train_image_paths)

# Print the result
print("Image mode summary:")
print(mode_summary)
# Out:
# Image mode summary:
# {'RGB': 995}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.bar(mode_summary.keys(), mode_summary.values(), color='pink')
plt.title("Image Mode Distribution (Train Set)")
plt.xlabel("Image Mode")
plt.ylabel("Number of Images")
plt.show()

# %% [markdown]
# # Histogram Intensity

# %%
image_Pneumonia = []
image_Normal = []
image_covid = []
count_1 = 0
count_2 = 0
count_3 = 0
for i in range(len(images)):
    if labels[i] == 'pneumonia' and count_1 < 2 :
        image_Pneumonia.append(images[i])
        count_1 += 1
    elif labels[i] == 'normal' and count_2 < 2 :
        image_Normal.append(images[i])
        count_2 += 1
    elif labels[i] == 'covid19' and count_3 < 2:
        image_covid.append(images[i])
        count_3 += 1

# %%
all_images = image_Pneumonia + image_Normal + image_covid

fig, axs = plt.subplots(6, 2, figsize=(10, 18))
fig.suptitle('Grayscale Image Intensity and Histograms', fontsize=16)

for i, img in enumerate(all_images):
    if img.dtype != np.uint8:
        img = np.clip(img * 255, 0, 255).astype(np.uint8)

    if len(img.shape) == 3 and img.shape[2] == 3:
        img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    else:
        img_gray = img

    axs[i, 0].imshow(img_gray, cmap='gray')
    axs[i, 0].set_title(f'Grayscale Image {i+1}')
    axs[i, 0].axis('off')

    hist = cv2.calcHist([img_gray], [0], None, [256], [0, 256])
    hist = hist.flatten()

    axs[i, 1].bar(range(256), hist, color='black', width=1)
    axs[i, 1].set_title(f'Histogram {i+1}')
    axs[i, 1].set_xlim([0, 256])
    axs[i, 1].set_xlabel('Pixel Intensity')
    axs[i, 1].set_ylabel('Frequency')

plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.show()

# %% [markdown]
# ## Comment: Pneumonia class which is the first one is morse dark in intenisty with high frequency, Normal with is the 3rd and 4th are centered and low frequency, the last ones which are covid are distributed with normal frequencies

# %% [markdown]
# # Visualizing a Sample of Each Class

# %%
classes = ['pneumonia', 'pneumonia', 'normal', 'normal', 'covid19', 'covid19']

fig, axs = plt.subplots(2, 3, figsize=(15, 8))

for i in range(2):
    for j in range(3):
        idx = i * 3 + j
        axs[i, j].imshow(all_images[idx])
        axs[i, j].set_title(classes[idx])
        axs[i, j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Checking for Very Dark/Bright Images

# %%
Dark_images = []
Light_images = []

for i, img in enumerate(images):
  if img.dtype != np.uint8:
        img = np.clip(img * 255, 0, 255).astype(np.uint8)
  img_array = np.array(img)
  mean_intensity = img_array.mean()

  if(mean_intensity < 60):
      print("images with index", i, "is too dark")
      Dark_images.append(img)

  if(mean_intensity > 200):
      print("images with index", i, "is too light")
      Light_images.append(img)
print(f"There are {len(Dark_images)} images that are too dark, and {len(Light_images)} images that are too light.")
# Out:
# images with index 210 is too dark
# images with index 374 is too light
# There are 1 images that are too dark, and 1 images that are too light.

# %% [markdown]
# ## Comment: Out of over 1,244 images, only 2 are considered low-quality, based on the assumption that their mean pixel intensity is below 60 or above 200

# %% [markdown]
# # Visualize intensity of Sample Images by Boxplots

# %%
all_images = image_Pneumonia + image_Normal + image_covid

classes = ['pneumonia'] * len(image_Pneumonia) + ['normal'] * len(image_Normal) + ['covid19'] * len(image_covid)

intensities_by_class = {cls: [] for cls in set(classes)}

for img, cls in zip(all_images, classes):

    if img.dtype != np.uint8:
        img = np.clip(img * 255, 0, 255).astype(np.uint8)

    if len(img.shape) == 3 and img.shape[2] == 3:
        img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    else:
        img_gray = img

    intensities = img_gray.flatten() / 255.0
    intensities_by_class[cls].extend(intensities)

data_to_plot = [intensities_by_class[cls] for cls in sorted(intensities_by_class.keys())]

plt.figure(figsize=(10, 6))
plt.boxplot(data_to_plot, vert=True, patch_artist=True)
plt.title('Boxplot of Image-Level Intensities by Class', fontsize=16)
plt.xlabel('Class')
plt.ylabel('Normalized Pixel Intensity')
plt.xticks(range(1, len(data_to_plot) + 1), sorted(intensities_by_class.keys()), rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # PCA to identify the separability of classes

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

X = images.reshape(images.shape[0], -1)
pca_2d = PCA(n_components=2)
X_2d = pca_2d.fit_transform(X)

unique_labels = sorted(set(labels))

clusters = []
for label in unique_labels:
  cluster =[]
  for i, l in enumerate(labels):
    if l == label:
      cluster.append(i)
  clusters.append(cluster)

for i, cluster in enumerate(clusters):
    plt.scatter(X_2d[cluster, 0], X_2d[cluster, 1], label=unique_labels[i], alpha=0.6)

plt.title("2D PCA Projection of Image Dataset")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend()
plt.show()
